# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Dataset from kaggle

# %%
#import file
df1 = pd.read_csv("dataset_kaggle.csv",encoding = "latin-1")

# %%
#information of data
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#drop column all Unnamed
df1.drop(df1.iloc[:,2:],inplace=True,axis=1)

# %%
#rename columns
df1.rename(columns={"v1": "label", "v2": "sms"},inplace=True)

# %%
 # see the first 5 data
df1.head(5)
# Out:
#   label                                                sms
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#count the number of missing values
df1.isna().sum()
# Out:
# label    0
# sms      0
# dtype: int64

# %%
#show counts of spam sms and not spam sms (ham)
print('The total number of spam and not spam message in our dataset is\n',df1['label'].value_counts())
# Out:
# The total number of spam and not spam message in our dataset is
#  label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
#number of rows and columns in the DataFrame.
df1.shape
# Out:
# (5572, 2)

# %%
#check duplicate value
df1.duplicated().sum()
# Out:
# 403

# %%
#drop duplicate value
df1=df1.drop_duplicates()

# %%
print('The total number of spam and not spam message in our dataset is\n',df1['label'].value_counts())
# Out:
# The total number of spam and not spam message in our dataset is
#  label
# ham     4516
# spam     653
# Name: count, dtype: int64

# %%
# create a bar plot of the counts of each unique value in the 'label' column
sns.countplot(x=df1['label'])
plt.show()

# %%
df1
# Out:
#      label                                                sms
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %% [markdown]
# - Dataset from research

# %%
#import file
df2 = pd.read_csv("dataset_research.csv",encoding = "latin-1")

# %%
#combines file
df = pd.concat([df1, df2], ignore_index=True)

# %%
df
# Out:
#      label                                                sms
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 6279  spam  You have won a Nokia 7250i. This is what you g...
# 6280  spam  Get ur 1st RINGTONE FREE NOW! Reply to this ms...
# 6281  spam  Ur cash-balance is currently 500 pounds - to m...
# 6282  spam  Records indicate you were involved in an accid...
# 6283  spam   call now 08707509020 Just 20p per min NTT Ltd...
#
# [6284 rows x 2 columns]

# %%
print('The total number of spam and not spam message in our dataset is\n',df['label'].value_counts())
# Out:
# The total number of spam and not spam message in our dataset is
#  label
# ham     4516
# spam    1768
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 359

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print('The total number of spam and not spam message in our dataset is\n',df['label'].value_counts())
# Out:
# The total number of spam and not spam message in our dataset is
#  label
# ham     4516
# spam    1409
# Name: count, dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 3.7 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24

# %%
import nltk
import re
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from sklearn.utils import resample

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
df['label'] = df['label'].map( {'spam': 1, 'ham': 0})
# Out:
# <ipython-input-25-b463ce2299f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['label'].map( {'spam': 1, 'ham': 0})

# %%
df
# Out:
#       label                                                sms
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 6274      1  Your SAM registration has been received! Click...
# 6279      1  You have won a Nokia 7250i. This is what you g...
# 6280      1  Get ur 1st RINGTONE FREE NOW! Reply to this ms...
# 6282      1  Records indicate you were involved in an accid...
# 6283      1   call now 08707509020 Just 20p per min NTT Ltd...
#
# [5925 rows x 2 columns]

# %%
# Copy the 'sms' column to the 'change_sms' column
df['change_sms'] = df['sms'].copy()

# Remove leading and trailing whitespaces from the 'change_sms' column
df['change_sms'] = df['change_sms'].str.strip()

# Convert all characters in the 'change_sms' column to lowercase
df['change_sms'] = df['change_sms'].str.lower()

# Expand contractions
df['change_sms'] = df['change_sms'].apply(lambda x: contractions.fix(x))
# Out:
# <ipython-input-27-659813654961>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['sms'].copy()
# <ipython-input-27-659813654961>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['change_sms'].str.strip()
# <ipython-input-27-659813654961>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['change_sms'].str.lower()
# <ipython-input-27-659813654961>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['change_sms'].apply(lambda x: contractions.fix(x))

# %%
df
# Out:
#       label                                                sms  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 6274      1  Your SAM registration has been received! Click...
# 6279      1  You have won a Nokia 7250i. This is what you g...
# 6280      1  Get ur 1st RINGTONE FREE NOW! Reply to this ms...
# 6282      1  Records indicate you were involved in an accid...
# 6283      1   call now 08707509020 Just 20p per min NTT Ltd...
#
#                                              change_sms
# 0     go until jurong point, crazy.. available only ...
# 1                       ok lar... joking wif you oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     you dun say so early hor... you c already then...
# 4     nah i do not think he goes to usf, he lives ar...
# ...                                                 ...
# 6274  your sam registration has been received! click...
# 6279  you have won a nokia 7250i. this is what you g...
# 6280  get you are 1st ringtone free now! reply to th...
# 6282  records indicate you were involved in an accid...
# 6283  call now 08707509020 just 20p per min ntt ltd,...
#
# [5925 rows x 3 columns]

# %%
def change_word_eng(sms):
    regex = r"(http(s)?:\/\/.)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)"
    sms = re.sub(regex, ' link ', sms)
    sms= re.sub(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b',' email ',sms)
    sms = re.sub(r'\b(?:\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\d{10})\b', ' phonenumber ', sms)
    sms = re.sub(r'\b(?:\d{3}[-\.\s]??\d{7})\b', ' phonenumber ', sms)
    sms = re.sub(r'\b(?:\d{2}[-\.\s]??\d{3}[-\.\s]??\d{4}|\d{9})\b', ' phonenumber ', sms)
    sms = re.sub(r'\b\d{10}\b', ' phonenumber ', sms)
    sms = re.sub(r'\b\d{9}\b', ' phonenumber ', sms)
    sms = re.sub(r'\d+', ' number ', sms)
    sms = re.sub(r'[£$฿]', ' moneysymbol ', sms)
    sms = re.sub(r'[\"]', ' ', sms)
    sms = re.sub(r'[^a-zA-Z\s\'\"]|^\'|\'$', '', sms)
    return sms


# Create a new column 'change_sms' by applying the function to 'sms' column
df['change_sms'] = df['change_sms'].apply(lambda x: change_word_eng(x))
# Out:
# <ipython-input-29-50d0c943b1b2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['change_sms'].apply(lambda x: change_word_eng(x))

# %%
df
# Out:
#       label                                                sms  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 6274      1  Your SAM registration has been received! Click...
# 6279      1  You have won a Nokia 7250i. This is what you g...
# 6280      1  Get ur 1st RINGTONE FREE NOW! Reply to this ms...
# 6282      1  Records indicate you were involved in an accid...
# 6283      1   call now 08707509020 Just 20p per min NTT Ltd...
#
#                                              change_sms
# 0     go until jurong point crazy available only in ...
# 1                             ok lar joking wif you oni
# 2     free entry in  number  a wkly comp to win fa c...
# 3       you dun say so early hor you c already then say
# 4     nah i do not think he goes to usf he lives aro...
# ...                                                 ...
# 6274  your sam registration has been received click ...
# 6279  you have won a nokia  number i this is what yo...
# 6280  get you are  number st ringtone free now reply...
# 6282  records indicate you were involved in an accid...
# 6283  call now  number  just  number p per min ntt l...
#
# [5925 rows x 3 columns]

# %%
# Remove punctuation
df['change_sms'] = df['change_sms'].apply(lambda x: re.sub(r'[^\w\d\s]|_\s*$', ' ', x))

# Remove whitespace between terms with single space
df['change_sms'] = df['change_sms'].apply(lambda x: re.sub(r'\s+', ' ', x))
# Out:
# <ipython-input-31-699dc787d415>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['change_sms'].apply(lambda x: re.sub(r'[^\w\d\s]|_\s*$', ' ', x))
# <ipython-input-31-699dc787d415>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['change_sms'] = df['change_sms'].apply(lambda x: re.sub(r'\s+', ' ', x))

# %%
#function for tokenize
def tokenize(df , model) :
  new_values = []
  for i in df.index:
    if model == "nltk":
      s = word_tokenize(df['change_sms'][i])
    new_values.append(s)
  df[model] = new_values
  return df

# %%
#tokenize the text in a DataFrame using NLTK
tokenize(df , "nltk")
# Out:
# <ipython-input-32-b4ec36622400>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[model] = new_values
#       label                                                sms  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 6274      1  Your SAM registration has been received! Click...
# 6279      1  You have won a Nokia 7250i. This is what you g...
# 6280      1  Get ur 1st RINGTONE FREE NOW! Reply to this ms...
# 6282      1  Records indicate you were involved in an accid...
# 6283      1   call now 08707509020 Just 20p per min NTT Ltd...
#
#                                              change_sms  \
# 0     go until jurong point crazy available only in ...
# 1                             ok lar joking wif you oni
# 2     free entry in number a wkly comp to win fa cup...
# 3       you dun say so early hor you c already then say
# 4     nah i do not think he goes to usf he lives aro...
# ...                                                 ...
# 6274  your sam registration has been received click ...
# 6279  you have won a nokia number i this is what you...
# 6280  get you are number st ringtone free now reply ...
# 6282  records indicate you were involved in an accid...
# 6283  call now number just number p per min ntt ltd ...
#
#                                                    nltk
# 0     [go, until, jurong, point, crazy, available, o...
# 1                      [ok, lar, joking, wif, you, oni]
# 2     [free, entry, in, number, a, wkly, comp, to, w...
# 3     [you, dun, say, so, early, hor, you, c, alread...
# 4     [nah, i, do, not, think, he, goes, to, usf, he...
# ...                                                 ...
# 6274  [your, sam, registration, has, been, received,...
# 6279  [you, have, won, a, nokia, number, i, this, is...
# 6280  [get, you, are, number, st, ringtone, free, no...
# 6282  [records, indicate, you, were, involved, in, a...
# 6283  [call, now, number, just, number, p, per, min,...
#
# [5925 rows x 4 columns]

# %%
# Initialize the lemmatizer
wl = WordNetLemmatizer()

#function to map POS tags to WordNet POS tags
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V') or tag in ['MD']:
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

#lemmatizer function
def lemmatizer(df):
    new_values = []
    for i in df.index:
        word_pos_tags = nltk.pos_tag(df['nltk'][i]) # Get position tags
        a = [wl.lemmatize(tag[0], get_wordnet_pos(tag[1])) for idx, tag in enumerate(word_pos_tags)] # Map the position tag and lemmatize the word/token
        new_values.append(a)
    df['nltk'] = new_values
    return df

# %%
# Lemmatize the 'nltk' column using the lemmatizer function
df['nltk'] = lemmatizer(df[['nltk']])

# Join the lemmatized tokens back into a single string in each row of the 'nltk' column
df['nltk'] = df['nltk'].apply(' '.join)
# Out:
# <ipython-input-34-29701191be3c>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = new_values
# <ipython-input-35-1a544be00279>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = lemmatizer(df[['nltk']])
# <ipython-input-35-1a544be00279>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = df['nltk'].apply(' '.join)

# %%
df
# Out:
#       label                                                sms  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 6274      1  Your SAM registration has been received! Click...
# 6279      1  You have won a Nokia 7250i. This is what you g...
# 6280      1  Get ur 1st RINGTONE FREE NOW! Reply to this ms...
# 6282      1  Records indicate you were involved in an accid...
# 6283      1   call now 08707509020 Just 20p per min NTT Ltd...
#
#                                              change_sms  \
# 0     go until jurong point crazy available only in ...
# 1                             ok lar joking wif you oni
# 2     free entry in number a wkly comp to win fa cup...
# 3       you dun say so early hor you c already then say
# 4     nah i do not think he goes to usf he lives aro...
# ...                                                 ...
# 6274  your sam registration has been received click ...
# 6279  you have won a nokia number i this is what you...
# 6280  get you are number st ringtone free now reply ...
# 6282  records indicate you were involved in an accid...
# 6283  call now number just number p per min ntt ltd ...
#
#                                                    nltk
# 0     go until jurong point crazy available only in ...
# 1                             ok lar joking wif you oni
# 2     free entry in number a wkly comp to win fa cup...
# 3       you dun say so early hor you c already then say
# 4     nah i do not think he go to usf he live around...
# ...                                                 ...
# 6274  your sam registration have be receive click he...
# 6279  you have win a nokia number i this be what you...
# 6280  get you be number st ringtone free now reply t...
# 6282  record indicate you be involve in an accident ...
# 6283  call now number just number p per min ntt ltd ...
#
# [5925 rows x 4 columns]

# %%
# Stopwords
stop_words = set(stopwords.words('english'))
df['nltk'] = df['nltk'].apply(lambda x: ' '.join(['' if word.lower().strip() in stop_words else word for word in x.split()]))

# Stemming
ss = SnowballStemmer("english")
df['nltk'] = df['nltk'].apply(lambda x: ' '.join([ss.stem(term) for term in x.split()]))

# Delete whitespace
df['nltk'] = df['nltk'].apply(lambda x: ' '.join(word.strip() for word in x.split() if word.strip()))
# Out:
# <ipython-input-37-725644f2dee2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = df['nltk'].apply(lambda x: ' '.join(['' if word.lower().strip() in stop_words else word for word in x.split()]))
# <ipython-input-37-725644f2dee2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = df['nltk'].apply(lambda x: ' '.join([ss.stem(term) for term in x.split()]))
# <ipython-input-37-725644f2dee2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = df['nltk'].apply(lambda x: ' '.join(word.strip() for word in x.split() if word.strip()))

# %%
df['nltk'].duplicated().sum()
# Out:
# 536

# %%
df.drop_duplicates(subset=['nltk'], keep='first', inplace=True)
# Out:
# <ipython-input-39-5a73740f885e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['nltk'], keep='first', inplace=True)

# %%
df['nltk'].duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       label                                                sms  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 6273      1  Double Mins & Double Txt & 1/2 price Call Mobi...
# 6274      1  Your SAM registration has been received! Click...
# 6279      1  You have won a Nokia 7250i. This is what you g...
# 6282      1  Records indicate you were involved in an accid...
# 6283      1   call now 08707509020 Just 20p per min NTT Ltd...
#
#                                              change_sms  \
# 0     go until jurong point crazy available only in ...
# 1                             ok lar joking wif you oni
# 2     free entry in number a wkly comp to win fa cup...
# 3       you dun say so early hor you c already then say
# 4     nah i do not think he goes to usf he lives aro...
# ...                                                 ...
# 6273  double mins double txt number number price cal...
# 6274  your sam registration has been received click ...
# 6279  you have won a nokia number i this is what you...
# 6282  records indicate you were involved in an accid...
# 6283  call now number just number p per min ntt ltd ...
#
#                                                    nltk
# 0     go jurong point crazi avail bugi n great world...
# 1                                   ok lar joke wif oni
# 2     free entri number wkli comp win fa cup final t...
# 3                       dun say earli hor c alreadi say
# 4                   nah think go usf live around though
# ...                                                 ...
# 6273  doubl min doubl txt number number price call m...
# 6274  sam registr receiv click complet process http ...
# 6279  win nokia number get win free auction take par...
# 6282  record indic involv accid last number number y...
# 6283  call number number p per min ntt ltd po box nu...
#
# [5389 rows x 4 columns]

# %% [markdown]
# - Data Augmentation

# %%
pip install textattack
# Out:
# Collecting textattack
#   Downloading textattack-0.3.10-py3-none-any.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.7/445.7 kB 5.4 MB/s eta 0:00:00
# Collecting bert-score>=0.3.5 (from textattack)
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from textattack) (0.6.2)
# Collecting flair (from textattack)
#   Downloading flair-0.13.1-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from textattack) (3.14.0)
# Collecting language-tool-python (from textattack)
#   Downloading language_tool_python-2.8-py3-none-any.whl (35 kB)
# Collecting lemminflect (from textattack)
#   Downloading lemminflect-0.2.3-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 14.1 MB/s eta 0:00:00
# Collecting lru-dict (from textattack)
#   Downloading lru_dict-1.3.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting datasets>=2.4.0 (from textattack)
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from textattack) (3.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.25.2)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from textattack) (2.0.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.11.4)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (2.2.1+cu121)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (4.40.2)
# Collecting terminaltables (from textattack)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from textattack) (4.66.4)
# Collecting word2number (from textattack)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting num2words (from textattack)
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from textattack) (10.1.0)
# Collecting pinyin>=0.4.0 (from textattack)
#   Downloading pinyin-0.4.0.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from textattack) (0.42.1)
# Collecting OpenHowNet (from textattack)
#   Downloading OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack) (24.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.4.0->textattack)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.7 MB/s eta 0:00:00
# Collecting xxhash (from datasets>=2.4.0->textattack)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.4.0->textattack)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets>=2.4.0->textattack)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack) (2024.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch!=1.8,>=1.7.0->textattack)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack) (0.4.3)
# Collecting boto3>=1.20.27 (from flair->textattack)
#   Downloading boto3-1.34.103-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 17.3 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2 (from flair->textattack)
#   Downloading bpemb-0.3.5-py3-none-any.whl (19 kB)
# Collecting conllu>=4.0 (from flair->textattack)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Collecting deprecated>=1.2.13 (from flair->textattack)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ftfy>=6.1.0 (from flair->textattack)
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (5.1.0)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.3.2)
# Collecting janome>=0.4.2 (from flair->textattack)
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 36.6 MB/s eta 0:00:00
# Collecting langdetect>=1.0.9 (from flair->textattack)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 35.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.9.4)
# Collecting mpld3>=0.3 (from flair->textattack)
#   Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 27.4 MB/s eta 0:00:00
# Collecting pptree>=3.1 (from flair->textattack)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-revgrad>=0.2.0 (from flair->textattack)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.2.2)
# Collecting segtok>=1.5.11 (from flair->textattack)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting sqlitedict>=2.0.0 (from flair->textattack)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.9.0)
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair->textattack)
#   Downloading transformer_smaller_training_vocab-0.4.0-py3-none-any.whl (14 kB)
# Collecting urllib3<2.0.0,>=1.0.0 (from flair->textattack)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 18.5 MB/s eta 0:00:00
# Collecting wikipedia-api>=0.5.7 (from flair->textattack)
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting semver<4.0.0,>=3.0.0 (from flair->textattack)
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from language-tool-python->textattack) (23.1.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from language-tool-python->textattack) (0.43.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->textattack) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->textattack) (1.4.2)
# Collecting docopt>=0.6.2 (from num2words->textattack)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting anytree (from OpenHowNet->textattack)
#   Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from OpenHowNet->textattack) (67.7.2)
# Collecting botocore<1.35.0,>=1.34.103 (from boto3>=1.20.27->flair->textattack)
#   Downloading botocore-1.34.103-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 69.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.27->flair->textattack)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.20.27->flair->textattack)
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair->textattack) (0.1.99)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->flair->textattack) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (4.0.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy>=6.1.0->flair->textattack) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair->textattack) (4.12.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->flair->textattack) (6.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect>=1.0.9->flair->textattack) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->flair->textattack) (3.5.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack) (3.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.7.0->textattack) (1.3.0)
# Collecting accelerate>=0.21.0 (from transformers>=4.30.0->textattack)
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair->textattack) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack) (1.7.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers>=4.30.0->textattack) (5.9.5)
# Building wheels for collected packages: pinyin, word2number, docopt, langdetect, pptree, sqlitedict
#   Building wheel for pinyin (setup.py) ... done
#   Created wheel for pinyin: filename=pinyin-0.4.0-py3-none-any.whl size=3630475 sha256=fe8fc558c62084182d2b9642fd2a656be7d24072a3f76a94d4f890fd4545ac4f
#   Stored in directory: /root/.cache/pip/wheels/33/38/af/616fc6f154aa5bae65a1da12b22d79943434269f0468ff9b3f
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=f332e575a1629141af15444306a02526c1b89aa3074155de256e00464edcdda1
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=1be4df7bb98107177829a49287d3e46be058129ab7e01ffbef57962d9b406185
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=57cd0eaebcf08e92ad6fd0edf8a99d4f52c97028787dc521e1ddbf0174926f6e
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4609 sha256=12b0187463d389466ebfe1be7e502fec841309ecb54f31ad9714e6f4aac14201
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=008d44ccafb3f35eb30c76511baa8946996dfaef17f713f8d06d37af354aefd4
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built pinyin word2number docopt langdetect pptree sqlitedict
# Installing collected packages: word2number, sqlitedict, pptree, pinyin, janome, docopt, xxhash, urllib3, terminaltables, semver, segtok, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, num2words, lru-dict, lemminflect, langdetect, jmespath, ftfy, dill, deprecated, conllu, anytree, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, botocore, wikipedia-api, s3transfer, OpenHowNet, nvidia-cusolver-cu12, mpld3, language-tool-python, huggingface-hub, bpemb, datasets, boto3, pytorch-revgrad, accelerate, bert-score, transformer-smaller-training-vocab, flair, textattack
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed OpenHowNet-2.0 accelerate-0.30.1 anytree-2.12.1 bert-score-0.3.13 boto3-1.34.103 botocore-1.34.103 bpemb-0.3.5 conllu-4.5.3 datasets-2.19.1 deprecated-1.2.14 dill-0.3.8 docopt-0.6.2 flair-0.13.1 ftfy-6.2.0 huggingface-hub-0.23.0 janome-0.5.0 jmespath-1.0.1 langdetect-1.0.9 language-tool-python-2.8 lemminflect-0.2.3 lru-dict-1.3.0 mpld3-0.5.10 multiprocess-0.70.16 num2words-0.5.13 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 pinyin-0.4.0 pptree-3.1 pytorch-revgrad-0.2.0 s3transfer-0.10.1 segtok-1.5.11 semver-3.0.2 sqlitedict-2.1.0 terminaltables-3.1.10 textattack-0.3.10 transformer-smaller-training-vocab-0.4.0 urllib3-1.26.18 wikipedia-api-0.6.0 word2number-1.1 xxhash-3.4.1

# %%
from textattack.augmentation import WordNetAugmenter
from textattack.augmentation import EmbeddingAugmenter
from sklearn.utils import shuffle
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Separate spam and ham messages
spam_messages = df[df['label'] == 1]['nltk']
ham_messages = df[df['label'] == 0]['nltk']

# Upsample the spam class using text augmentation with synonym replacement
aug = WordNetAugmenter()

num_to_generate = len(ham_messages) - len(spam_messages)

generated_messages = set()  # Archive newly created messages to check for duplicates

for original_message in spam_messages:
    while len(generated_messages) < num_to_generate:
        # Apply synonym replacement augmentation
        augmented_message = aug.augment(original_message)

        # Make sure not replaced
        augmented_message = re.sub(r'\blink\b', 'link', str(augmented_message))
        augmented_message = re.sub(r'\bphonenumber\b', 'phonenumber', str(augmented_message))
        augmented_message = re.sub(r'\bnumber\b', 'number', str(augmented_message))
        augmented_message = re.sub(r'\bemail\b', 'email', str(augmented_message))
        augmented_message = re.sub(r'\bmoneysymbol\b', 'moneysymbol', str(augmented_message))
        # Remove square brackets, single quotes, and double quotes
        augmented_message = re.sub(r'[\[\]\'"]', '', augmented_message)

        if augmented_message not in generated_messages and augmented_message not in spam_messages:
            generated_messages.add(augmented_message)

# Create a new DataFrame with the original spam messages and the augmented ones
augmented_df = pd.DataFrame({'nltk': list(generated_messages), 'label': 1})
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
augmented_df
# Out:
#                                                    nltk  label
# 0     gratuitous entri number wkli comp profits fa c...      1
# 1     free entri act wkli comp win fa cup final tkts...      1
# 2     free entri list wkli comp win fa cup terminal ...      1
# 3     absolve entri number wkli comp win fa cup fina...      1
# 4     free entri come wkli comp win fa cup final tkt...      1
# ...                                                 ...    ...
# 3544  free entri list wkli comp win fa cup final tkt...      1
# 3545  free entri number wkli comp win fa cup final t...      1
# 3546  free entri number wkli comp win fa cup final t...      1
# 3547  justify entri number wkli comp win fa cup fina...      1
# 3548  free entri enumerate wkli comp win fa cup fina...      1
#
# [3549 rows x 2 columns]

# %%
augmented_df['nltk'].duplicated().sum()
# Out:
# 0

# %%
# Concatenate the original DataFrame and the augmented DataFrame
df = pd.concat([df, augmented_df], ignore_index=True)

# %%
df
# Out:
#       label                                                sms  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 8933      1                                                NaN
# 8934      1                                                NaN
# 8935      1                                                NaN
# 8936      1                                                NaN
# 8937      1                                                NaN
#
#                                              change_sms  \
# 0     go until jurong point crazy available only in ...
# 1                             ok lar joking wif you oni
# 2     free entry in number a wkly comp to win fa cup...
# 3       you dun say so early hor you c already then say
# 4     nah i do not think he goes to usf he lives aro...
# ...                                                 ...
# 8933                                                NaN
# 8934                                                NaN
# 8935                                                NaN
# 8936                                                NaN
# 8937                                                NaN
#
#                                                    nltk
# 0     go jurong point crazi avail bugi n great world...
# 1                                   ok lar joke wif oni
# 2     free entri number wkli comp win fa cup final t...
# 3                       dun say earli hor c alreadi say
# 4                   nah think go usf live around though
# ...                                                 ...
# 8933  free entri list wkli comp win fa cup final tkt...
# 8934  free entri number wkli comp win fa cup final t...
# 8935  free entri number wkli comp win fa cup final t...
# 8936  justify entri number wkli comp win fa cup fina...
# 8937  free entri enumerate wkli comp win fa cup fina...
#
# [8938 rows x 4 columns]

# %%
# Shuffle the DataFrame
balanced_df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
balanced_df
# Out:
#       label                                                sms  \
# 0         1                                                NaN
# 1         0        Oh wow thats gay. Will firmware update help
# 2         1                                                NaN
# 3         1                                                NaN
# 4         1                                                NaN
# ...     ...                                                ...
# 8933      1                                                NaN
# 8934      1  You won't believe it but it's true. It's Incre...
# 8935      1                                                NaN
# 8936      0  see, i knew giving you a break a few times wou...
# 8937      1                                                NaN
#
#                                              change_sms  \
# 0                                                   NaN
# 1          oh wow that is gay will firmware update help
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8933                                                NaN
# 8934  you will not believe it but it is true it is i...
# 8935                                                NaN
# 8936  see i knew giving you a break a few times woul...
# 8937                                                NaN
#
#                                                    nltk
# 0     detached entri number wkli comp win fa cup fin...
# 1                         oh wow gay firmwar updat help
# 2     disengage entri number wkli comprehensive win ...
# 3     free entri number wkli comp win fa cup final t...
# 4     free entri issue wkli comp win fa cup concludi...
# ...                                                 ...
# 8933  free entri numeral wkli comp win fa cup final ...
# 8934  believ true incred txts repli g learn truli am...
# 8935  free entri act wkli comp win fa cup final tkts...
# 8936  see knew give break time woul lead alway want ...
# 8937  free entri number wkli comp win fa cup conclud...
#
# [8938 rows x 4 columns]

# %%
balanced_df['label'].value_counts()
# Out:
# label
# 1    4469
# 0    4469
# Name: count, dtype: int64

# %%
balanced_df['nltk'].duplicated().sum()
# Out:
# 0

# %%
duplicated_rows = balanced_df.loc[balanced_df['nltk'].duplicated(), :]
print(duplicated_rows)
# Out:
# Empty DataFrame
# Columns: [label, sms, change_sms, nltk]
# Index: []

# %%
# remove duplicated messages
balanced_df.drop_duplicates(subset=['nltk'], inplace=True)

# %%
# Select the row index for processing
n = 1

# Split the text into words
words = balanced_df['nltk'][n].split()

# Count the number of words
word_count = len(words)

# Print the original text, word count, and the list of words
print("sms: ", balanced_df['nltk'][n])
print("\ncount: ", word_count)
print("nltk: ", words)
# Out:
# sms:  oh wow gay firmwar updat help
#
# count:  6
# nltk:  ['oh', 'wow', 'gay', 'firmwar', 'updat', 'help']

# %%
# Calculate the number of words in each text
balanced_df['num_words'] = balanced_df['nltk'].apply(lambda x: len(x.split()))

# Find the row with the maximum number of words
max_words_row = balanced_df.loc[balanced_df['num_words'].idxmax()]

# Print the text in the row with the maximum number of words
print("Text in the row with the maximum number of words:")
print(max_words_row['nltk'])

# Print the number of words in the row with the maximum number of words
print("Number of words in the row with the maximum number of words:", max_words_row['num_words'])

# Store the maximum number of words for further use
max_len = max_words_row['num_words']
# Out:
# Text in the row with the maximum number of words:
# love start attractioni feel need everi time around link first thing come thoughtsi would start day end link everi time link everi breath link life happen around link life name heri would cri link give happi take sorrowsi readi fight anyon heri love crazi thing link proov anyon girl beauti ladi whole planeti alway sing prais link start make chicken curri end maki link beauti link get everi morn thank god day mei would like say link tell later
# Number of words in the row with the maximum number of words: 79

# %%
print(max_len)
# Out:
# 79

# %%
balanced_df
# Out:
#       label                                                sms  \
# 0         1                                                NaN
# 1         0        Oh wow thats gay. Will firmware update help
# 2         1                                                NaN
# 3         1                                                NaN
# 4         1                                                NaN
# ...     ...                                                ...
# 8933      1                                                NaN
# 8934      1  You won't believe it but it's true. It's Incre...
# 8935      1                                                NaN
# 8936      0  see, i knew giving you a break a few times wou...
# 8937      1                                                NaN
#
#                                              change_sms  \
# 0                                                   NaN
# 1          oh wow that is gay will firmware update help
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8933                                                NaN
# 8934  you will not believe it but it is true it is i...
# 8935                                                NaN
# 8936  see i knew giving you a break a few times woul...
# 8937                                                NaN
#
#                                                    nltk  num_words
# 0     detached entri number wkli comp win fa cup fin...         25
# 1                         oh wow gay firmwar updat help          6
# 2     disengage entri number wkli comprehensive win ...         25
# 3     free entri number wkli comp win fa cup final t...         25
# 4     free entri issue wkli comp win fa cup concludi...         25
# ...                                                 ...        ...
# 8933  free entri numeral wkli comp win fa cup final ...         25
# 8934  believ true incred txts repli g learn truli am...         12
# 8935  free entri act wkli comp win fa cup final tkts...         25
# 8936  see knew give break time woul lead alway want ...         32
# 8937  free entri number wkli comp win fa cup conclud...         25
#
# [8938 rows x 5 columns]

# %% [markdown]
# - Import file of final dataset

# %%
balanced_df.to_csv('ta_finaldata.csv', index=False, encoding='utf-8-sig')

# %%
# Load file
final_df_path = "ta_finaldata.csv"
final_df = pd.read_csv(final_df_path)

# %%
import _utils as fn
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.layers import Embedding, Dense,Dropout,Flatten,Bidirectional, LSTM, SimpleRNN, Conv1D, MaxPooling1D,GlobalMaxPooling1D
from keras.layers import GRU
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping

# %%
final_df['nltk'][1]
# Out:
# 'oh wow gay firmwar updat help'

# %% [markdown]
# - Word Embedding โดยใช้ Embedding Layer แบบทั่วไป

# %%
print("max_len: ", max_len)
# Out:
# max_len:  79

# %%
embedding_dim=max_len

# %%
#Splitting the data into dependent and independent variables i.e, features and the target columns
X = final_df['nltk']
Y =  final_df['label']

#Splitting the data such that 20% will be used for testing and the remaining 82% will be used for training.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
len(X_train),len(Y_train),len(X_test),len(Y_test)
# Out:
# (7150, 7150, 1788, 1788)

# %%
X_train = [str(text) if pd.notnull(text) else '' for text in X_train]

# Creating a Tokenizer and fitting it on the cleaned text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# Defining special tokens and updating the tokenizer's word index
special_vocab = {'<PAD>': 0, '<START>': 1, '<UNKNOWN>': 2, '<UNUSED>': 3}
tokenizer.word_index = {**special_vocab, **{word: index + 3 for word, index in tokenizer.word_index.items()}}

# %%
tokenizer.word_index
# Out:
# {'<PAD>': 0,
#  '<START>': 1,
#  '<UNKNOWN>': 2,
#  '<UNUSED>': 3,
#  'number': 4,
#  'entri': 5,
#  'fa': 6,
#  'txt': 7,
#  'text': 8,
#  'st': 9,
#  'receiv': 10,
#  'appli': 11,
#  'wkli': 12,
#  'tkts': 13,
#  'questionstd': 14,
#  'ratetc': 15,
#  'may': 16,
#  'comp': 17,
#  'cup': 18,
#  'final': 19,
#  'win': 20,
#  'free': 21,
#  'get': 22,
#  'come': 23,
#  'link': 24,
#  'call': 25,
#  'go': 26,
#  'bit': 27,
#  'act': 28,
#  'amount': 29,
#  'count': 30,
#  'turn': 31,
#  'total': 32,
#  'enumerate': 33,
#  'list': 34,
#  'numerate': 35,
#  'figure': 36,
#  'numeral': 37,
#  'issue': 38,
#  'routine': 39,
#  'moneysymbol': 40,
#  'know': 41,
#  'want': 42,
#  'like': 43,
#  'ltgt': 44,
#  'send': 45,
#  'love': 46,
#  'day': 47,
#  'ok': 48,
#  'time': 49,
#  'good': 50,
#  'tell': 51,
#  'think': 52,
#  'say': 53,
#  'see': 54,
#  'one': 55,
#  'week': 56,
#  'need': 57,
#  'make': 58,
#  'home': 59,
#  'today': 60,
#  'mobil': 61,
#  'messag': 62,
#  'take': 63,
#  'lor': 64,
#  'repli': 65,
#  'back': 66,
#  'stop': 67,
#  'r': 68,
#  'pleas': 69,
#  'still': 70,
#  'new': 71,
#  'phone': 72,
#  'n': 73,
#  'last': 74,
#  'hi': 75,
#  'well': 76,
#  'da': 77,
#  'sorri': 78,
#  'ask': 79,
#  'claim': 80,
#  'miss': 81,
#  'give': 82,
#  'leav': 83,
#  'dear': 84,
#  'meet': 85,
#  'wait': 86,
#  'work': 87,
#  'great': 88,
#  'thing': 89,
#  'tomorrow': 90,
#  'u': 91,
#  'oh': 92,
#  'thank': 93,
#  'night': 94,
#  'would': 95,
#  'happi': 96,
#  'hope': 97,
#  'tri': 98,
#  'much': 99,
#  'hey': 100,
#  'wat': 101,
#  'p': 102,
#  'later': 103,
#  'min': 104,
#  'let': 105,
#  'find': 106,
#  'late': 107,
#  'c': 108,
#  'friend': 109,
#  'prize': 110,
#  'alreadi': 111,
#  'even': 112,
#  'way': 113,
#  'right': 114,
#  'feel': 115,
#  'custom': 116,
#  'nokia': 117,
#  'e': 118,
#  'contact': 119,
#  'k': 120,
#  'keep': 121,
#  'phonenumb': 122,
#  'pls': 123,
#  'yeah': 124,
#  'babe': 125,
#  'realli': 126,
#  'pick': 127,
#  'life': 128,
#  'yes': 129,
#  'year': 130,
#  'care': 131,
#  'buy': 132,
#  'b': 133,
#  'tone': 134,
#  'sleep': 135,
#  'soon': 136,
#  'sure': 137,
#  'finish': 138,
#  'cash': 139,
#  'servic': 140,
#  'succeed': 141,
#  'anyth': 142,
#  'chat': 143,
#  'ill': 144,
#  'everi': 145,
#  'lol': 146,
#  'help': 147,
#  'morn': 148,
#  'also': 149,
#  'cupful': 150,
#  'urgent': 151,
#  'use': 152,
#  'gain': 153,
#  'start': 154,
#  'watch': 155,
#  'someth': 156,
#  'next': 157,
#  'tonight': 158,
#  'show': 159,
#  'award': 160,
#  'net': 161,
#  'acquire': 162,
#  'comprehensive': 163,
#  'end': 164,
#  'devoid': 165,
#  'offer': 166,
#  'schoolbook': 167,
#  'shop': 168,
#  'transfuse': 169,
#  'look': 170,
#  'textbook': 171,
#  'live': 172,
#  'detached': 173,
#  'could': 174,
#  'concluding': 175,
#  'talk': 176,
#  'guy': 177,
#  'month': 178,
#  'v': 179,
#  'wan': 180,
#  'unblock': 181,
#  'amp': 182,
#  'someon': 183,
#  'complimentary': 184,
#  'pay': 185,
#  'justify': 186,
#  'disembarrass': 187,
#  'whitethorn': 188,
#  'per': 189,
#  'account': 190,
#  'mean': 191,
#  'co': 192,
#  'box': 193,
#  'costless': 194,
#  'place': 195,
#  'yet': 196,
#  'name': 197,
#  'terminal': 198,
#  'x': 199,
#  'wish': 200,
#  'gratuitous': 201,
#  'discharge': 202,
#  'first': 203,
#  'collect': 204,
#  'winnings': 205,
#  'class': 206,
#  'ya': 207,
#  'pm': 208,
#  'hour': 209,
#  'dun': 210,
#  'rid': 211,
#  'smile': 212,
#  'fine': 213,
#  'eat': 214,
#  'peopl': 215,
#  'w': 216,
#  'plan': 217,
#  'mani': 218,
#  'profits': 219,
#  'reach': 220,
#  'exempt': 221,
#  'liberate': 222,
#  'money': 223,
#  'absolve': 224,
#  'minut': 225,
#  'thk': 226,
#  'advance': 227,
#  'spare': 228,
#  'nice': 229,
#  'resign': 230,
#  'stuff': 231,
#  'around': 232,
#  'happen': 233,
#  'hear': 234,
#  'draw': 235,
#  'loose': 236,
#  'relinquish': 237,
#  'word': 238,
#  'unfreeze': 239,
#  'release': 240,
#  'destitute': 241,
#  'cool': 242,
#  'unloose': 243,
#  'hello': 244,
#  'innocent': 245,
#  'play': 246,
#  'best': 247,
#  'readi': 248,
#  'mayb': 249,
#  'person': 250,
#  'gratis': 251,
#  'weekend': 252,
#  'fuck': 253,
#  'haha': 254,
#  'girl': 255,
#  'forget': 256,
#  'dislodge': 257,
#  'job': 258,
#  'relieve': 259,
#  'guarante': 260,
#  'unloosen': 261,
#  'barren': 262,
#  'never': 263,
#  'tc': 264,
#  'yo': 265,
#  'gud': 266,
#  'enjoy': 267,
#  'fun': 268,
#  'disengage': 269,
#  'special': 270,
#  'voucher': 271,
#  'lot': 272,
#  'chanc': 273,
#  'car': 274,
#  'bad': 275,
#  'problem': 276,
#  'guess': 277,
#  'yup': 278,
#  'game': 279,
#  'hr': 280,
#  'long': 281,
#  'check': 282,
#  'big': 283,
#  'though': 284,
#  'mind': 285,
#  'hous': 286,
#  'cost': 287,
#  'pic': 288,
#  'dat': 289,
#  'lar': 290,
#  'book': 291,
#  'anoth': 292,
#  'lunch': 293,
#  'ppm': 294,
#  'drive': 295,
#  'bring': 296,
#  'join': 297,
#  'probabl': 298,
#  'network': 299,
#  'alway': 300,
#  'wake': 301,
#  'real': 302,
#  'date': 303,
#  'jus': 304,
#  'card': 305,
#  'charg': 306,
#  'quit': 307,
#  'kiss': 308,
#  'speak': 309,
#  'noth': 310,
#  'g': 311,
#  'bed': 312,
#  'line': 313,
#  'put': 314,
#  'shit': 315,
#  'stay': 316,
#  'xxx': 317,
#  'rememb': 318,
#  'liberal': 319,
#  'room': 320,
#  'holiday': 321,
#  'dinner': 322,
#  'chang': 323,
#  'might': 324,
#  'worri': 325,
#  'th': 326,
#  'pobox': 327,
#  'boy': 328,
#  'sir': 329,
#  'wonder': 330,
#  'earli': 331,
#  'inform': 332,
#  'half': 333,
#  'code': 334,
#  'updat': 335,
#  'aight': 336,
#  'detail': 337,
#  'sm': 338,
#  'face': 339,
#  'orang': 340,
#  'rate': 341,
#  'anyway': 342,
#  'princess': 343,
#  'bus': 344,
#  'hurt': 345,
#  'video': 346,
#  'yr': 347,
#  'littl': 348,
#  'offic': 349,
#  'po': 350,
#  'god': 351,
#  'test': 352,
#  'camera': 353,
#  'select': 354,
#  'pound': 355,
#  'colour': 356,
#  'pa': 357,
#  'onlin': 358,
#  'liao': 359,
#  'everyth': 360,
#  'wk': 361,
#  'landlin': 362,
#  'lose': 363,
#  'point': 364,
#  'nite': 365,
#  'actual': 366,
#  'leh': 367,
#  'town': 368,
#  'abl': 369,
#  'man': 370,
#  'thanx': 371,
#  'heart': 372,
#  'doubl': 373,
#  'question': 374,
#  'answer': 375,
#  'sexi': 376,
#  'den': 377,
#  'sweet': 378,
#  'run': 379,
#  'mob': 380,
#  'gift': 381,
#  'sinc': 382,
#  'kind': 383,
#  'afternoon': 384,
#  'tv': 385,
#  'ah': 386,
#  'dad': 387,
#  'drop': 388,
#  'els': 389,
#  'bath': 390,
#  'price': 391,
#  'haf': 392,
#  'two': 393,
#  'uk': 394,
#  'walk': 395,
#  'bank': 396,
#  'age': 397,
#  'wif': 398,
#  'rington': 399,
#  'babi': 400,
#  'world': 401,
#  'dis': 402,
#  'poli': 403,
#  'ever': 404,
#  'top': 405,
#  'sit': 406,
#  'mate': 407,
#  'credit': 408,
#  'part': 409,
#  'bonus': 410,
#  'sound': 411,
#  'lesson': 412,
#  'pain': 413,
#  'ard': 414,
#  'download': 415,
#  'attempt': 416,
#  'nd': 417,
#  'okay': 418,
#  'school': 419,
#  'hot': 420,
#  'email': 421,
#  'pmin': 422,
#  'head': 423,
#  'follow': 424,
#  'drink': 425,
#  'shall': 426,
#  'hair': 427,
#  'order': 428,
#  'set': 429,
#  'post': 430,
#  'lei': 431,
#  'import': 432,
#  'xx': 433,
#  'studi': 434,
#  'away': 435,
#  'break': 436,
#  'movi': 437,
#  'complet': 438,
#  'busi': 439,
#  'hold': 440,
#  'till': 441,
#  'due': 442,
#  'without': 443,
#  'must': 444,
#  'wot': 445,
#  'sch': 446,
#  'dog': 447,
#  'dream': 448,
#  'hav': 449,
#  'smoke': 450,
#  'lucki': 451,
#  'second': 452,
#  'id': 453,
#  'mom': 454,
#  'valid': 455,
#  'goin': 456,
#  'address': 457,
#  'full': 458,
#  'food': 459,
#  'enter': 460,
#  'birthday': 461,
#  'easi': 462,
#  'await': 463,
#  'sad': 464,
#  'juz': 465,
#  'cos': 466,
#  'open': 467,
#  'content': 468,
#  'choos': 469,
#  'brother': 470,
#  'trip': 471,
#  'tot': 472,
#  'si': 473,
#  'compani': 474,
#  'rs': 475,
#  'neva': 476,
#  'either': 477,
#  'music': 478,
#  'tscs': 479,
#  'believ': 480,
#  'togeth': 481,
#  'deliveri': 482,
#  'aft': 483,
#  'train': 484,
#  'famili': 485,
#  'wen': 486,
#  'bt': 487,
#  'gr': 488,
#  'bore': 489,
#  'dude': 490,
#  'read': 491,
#  'winner': 492,
#  'current': 493,
#  'log': 494,
#  'enough': 495,
#  'player': 496,
#  'atm': 497,
#  'huh': 498,
#  'sell': 499,
#  'til': 500,
#  'click': 501,
#  'expir': 502,
#  'news': 503,
#  'spend': 504,
#  'colleg': 505,
#  'alright': 506,
#  'ltd': 507,
#  'saw': 508,
#  'everyon': 509,
#  'mail': 510,
#  'j': 511,
#  'nt': 512,
#  'plus': 513,
#  'exam': 514,
#  'awesom': 515,
#  'anytim': 516,
#  'visit': 517,
#  'avail': 518,
#  'decid': 519,
#  'yesterday': 520,
#  'move': 521,
#  'paytm': 522,
#  'opt': 523,
#  'valu': 524,
#  'worth': 525,
#  'india': 526,
#  'bill': 527,
#  'alon': 528,
#  'invit': 529,
#  'beauti': 530,
#  'differ': 531,
#  'direct': 532,
#  'land': 533,
#  'search': 534,
#  'listen': 535,
#  'true': 536,
#  'crazi': 537,
#  'caller': 538,
#  'wit': 539,
#  'simpl': 540,
#  'laugh': 541,
#  'camcord': 542,
#  'parti': 543,
#  'boytoy': 544,
#  'mobileupd': 545,
#  'mu': 546,
#  'noe': 547,
#  'oso': 548,
#  'rite': 549,
#  'fanci': 550,
#  'plz': 551,
#  'ltdecimalgt': 552,
#  'gd': 553,
#  'system': 554,
#  'activ': 555,
#  'wid': 556,
#  'congratul': 557,
#  'within': 558,
#  'ring': 559,
#  'frnd': 560,
#  'unsubscrib': 561,
#  'old': 562,
#  'wife': 563,
#  'whatev': 564,
#  'de': 565,
#  'match': 566,
#  'save': 567,
#  'pmessag': 568,
#  'area': 569,
#  'fone': 570,
#  'mum': 571,
#  'eve': 572,
#  'wil': 573,
#  'msg': 574,
#  'pub': 575,
#  'far': 576,
#  'close': 577,
#  'sat': 578,
#  'remind': 579,
#  'valentin': 580,
#  'fast': 581,
#  'friday': 582,
#  'hand': 583,
#  'seem': 584,
#  'xmas': 585,
#  'fri': 586,
#  'reason': 587,
#  'support': 588,
#  'possibl': 589,
#  'privat': 590,
#  'cut': 591,
#  'add': 592,
#  'smth': 593,
#  'cum': 594,
#  'sea': 595,
#  'freemsg': 596,
#  'uncl': 597,
#  'cours': 598,
#  'sun': 599,
#  'touch': 600,
#  'club': 601,
#  'hit': 602,
#  'store': 603,
#  'sort': 604,
#  'ha': 605,
#  'nope': 606,
#  'die': 607,
#  'info': 608,
#  'hop': 609,
#  'film': 610,
#  'congrat': 611,
#  'ticket': 612,
#  'f': 613,
#  'side': 614,
#  'welcom': 615,
#  'parent': 616,
#  'sex': 617,
#  'friendship': 618,
#  'hungri': 619,
#  'secret': 620,
#  'carlo': 621,
#  'snow': 622,
#  'pretti': 623,
#  'joke': 624,
#  'record': 625,
#  'suppos': 626,
#  'shower': 627,
#  'statement': 628,
#  'thought': 629,
#  'eh': 630,
#  'rain': 631,
#  'oredi': 632,
#  'mr': 633,
#  'deal': 634,
#  'sister': 635,
#  'mths': 636,
#  'song': 637,
#  'wq': 638,
#  'promis': 639,
#  'optout': 640,
#  'issu': 641,
#  'anyon': 642,
#  'hl': 643,
#  'tomo': 644,
#  'eg': 645,
#  'interest': 646,
#  'deliv': 647,
#  'project': 648,
#  'least': 649,
#  'treat': 650,
#  'mine': 651,
#  'light': 652,
#  'safe': 653,
#  'txts': 654,
#  'motorola': 655,
#  'forward': 656,
#  'park': 657,
#  'recent': 658,
#  'gym': 659,
#  'tel': 660,
#  'upgrad': 661,
#  'comput': 662,
#  'team': 663,
#  'outsid': 664,
#  'l': 665,
#  'confirm': 666,
#  'sae': 667,
#  'term': 668,
#  'grin': 669,
#  'short': 670,
#  'knw': 671,
#  'almost': 672,
#  'photo': 673,
#  'road': 674,
#  'fr': 675,
#  'goodmorn': 676,
#  'appl': 677,
#  'via': 678,
#  'catch': 679,
#  'txting': 680,
#  'darren': 681,
#  'fren': 682,
#  'usual': 683,
#  'cheap': 684,
#  'clear': 685,
#  'hard': 686,
#  'connect': 687,
#  'access': 688,
#  'etc': 689,
#  'im': 690,
#  'hospit': 691,
#  'case': 692,
#  'swing': 693,
#  'dont': 694,
#  'singl': 695,
#  'chikku': 696,
#  'coupl': 697,
#  'ipod': 698,
#  'figur': 699,
#  'clean': 700,
#  'bout': 701,
#  'rental': 702,
#  'ish': 703,
#  'ugh': 704,
#  'sometim': 705,
#  'soni': 706,
#  'idea': 707,
#  'mah': 708,
#  'scream': 709,
#  'quiz': 710,
#  'understand': 711,
#  'ph': 712,
#  'door': 713,
#  'rent': 714,
#  'subscrib': 715,
#  'app': 716,
#  'return': 717,
#  'christma': 718,
#  'surpris': 719,
#  'summer': 720,
#  'identifi': 721,
#  'moment': 722,
#  'drug': 723,
#  'across': 724,
#  'remov': 725,
#  'expect': 726,
#  'load': 727,
#  'rock': 728,
#  'gal': 729,
#  'discount': 730,
#  'member': 731,
#  'sub': 732,
#  'coz': 733,
#  'fl': 734,
#  'payment': 735,
#  'mm': 736,
#  'luck': 737,
#  'difficult': 738,
#  'regard': 739,
#  'oki': 740,
#  'kid': 741,
#  'doctor': 742,
#  'stori': 743,
#  'na': 744,
#  'loan': 745,
#  'chennai': 746,
#  'reward': 747,
#  'paper': 748,
#  'wow': 749,
#  'yar': 750,
#  'england': 751,
#  'fantast': 752,
#  'water': 753,
#  'forev': 754,
#  'notic': 755,
#  'near': 756,
#  'wana': 757,
#  'fill': 758,
#  'pas': 759,
#  'cd': 760,
#  'internet': 761,
#  'cancel': 762,
#  'horni': 763,
#  'pete': 764,
#  'process': 765,
#  'basic': 766,
#  'secur': 767,
#  'saturday': 768,
#  'unredeem': 769,
#  'poor': 770,
#  'din': 771,
#  'darlin': 772,
#  'gas': 773,
#  'request': 774,
#  'gbp': 775,
#  'prob': 776,
#  'meh': 777,
#  'abiola': 778,
#  'shes': 779,
#  'bb': 780,
#  'semest': 781,
#  'regist': 782,
#  'extra': 783,
#  'small': 784,
#  'savamob': 785,
#  'warm': 786,
#  'learn': 787,
#  'frnds': 788,
#  'stand': 789,
#  'offici': 790,
#  'eye': 791,
#  'flirt': 792,
#  'refund': 793,
#  'sport': 794,
#  'euro': 795,
#  'write': 796,
#  'angri': 797,
#  'jay': 798,
#  'rest': 799,
#  'fix': 800,
#  'kate': 801,
#  'marri': 802,
#  'serious': 803,
#  'bid': 804,
#  'norm': 805,
#  'unlimit': 806,
#  'hmv': 807,
#  'flag': 808,
#  'slow': 809,
#  'throw': 810,
#  'cover': 811,
#  'fact': 812,
#  'user': 813,
#  'respond': 814,
#  'slave': 815,
#  'tire': 816,
#  'crave': 817,
#  'becom': 818,
#  'reveal': 819,
#  'sick': 820,
#  'hurri': 821,
#  'la': 822,
#  'march': 823,
#  'key': 824,
#  'somewher': 825,
#  'mark': 826,
#  'somebodi': 827,
#  'tht': 828,
#  'disturb': 829,
#  'sunshin': 830,
#  'dvd': 831,
#  'noida': 832,
#  'correct': 833,
#  'hee': 834,
#  'login': 835,
#  'quick': 836,
#  'local': 837,
#  'tax': 838,
#  'success': 839,
#  'digit': 840,
#  'complimentari': 841,
#  'hp': 842,
#  'whole': 843,
#  'transfer': 844,
#  'station': 845,
#  'travel': 846,
#  'truth': 847,
#  'gay': 848,
#  'nah': 849,
#  'hmmm': 850,
#  'normal': 851,
#  'al': 852,
#  'oper': 853,
#  'anymor': 854,
#  'wine': 855,
#  'ten': 856,
#  'present': 857,
#  'laptop': 858,
#  'xy': 859,
#  'sms': 860,
#  'futur': 861,
#  'fantasi': 862,
#  'john': 863,
#  'cheer': 864,
#  'rpli': 865,
#  'ago': 866,
#  'type': 867,
#  'wc': 868,
#  'ladi': 869,
#  'share': 870,
#  'glad': 871,
#  'file': 872,
#  'comin': 873,
#  'er': 874,
#  'especi': 875,
#  'auction': 876,
#  'ki': 877,
#  'ntt': 878,
#  'teas': 879,
#  'voic': 880,
#  'facebook': 881,
#  'custcar': 882,
#  'oop': 883,
#  'page': 884,
#  'monday': 885,
#  'ni': 886,
#  'entitl': 887,
#  'sec': 888,
#  'ptone': 889,
#  'daddi': 890,
#  'spree': 891,
#  'howev': 892,
#  'round': 893,
#  'fat': 894,
#  'hiya': 895,
#  'goto': 896,
#  'tampa': 897,
#  'cashbal': 898,
#  'maxim': 899,
#  'cashin': 900,
#  'cc': 901,
#  'unless': 902,
#  'medic': 903,
#  'hotel': 904,
#  'power': 905,
#  'doin': 906,
#  'kick': 907,
#  'felt': 908,
#  'wednesday': 909,
#  'pictur': 910,
#  'onto': 911,
#  'vodafon': 912,
#  'tonit': 913,
#  'vl': 914,
#  'bluetooth': 915,
#  'group': 916,
#  'wear': 917,
#  'space': 918,
#  'tuesday': 919,
#  'il': 920,
#  'q': 921,
#  'yep': 922,
#  'block': 923,
#  'opinion': 924,
#  'roommat': 925,
#  'possess': 926,
#  'awak': 927,
#  'instead': 928,
#  'experi': 929,
#  'other': 930,
#  'step': 931,
#  'airtel': 932,
#  'arrang': 933,
#  'holder': 934,
#  'sim': 935,
#  'dollar': 936,
#  'chariti': 937,
#  'wun': 938,
#  'wrong': 939,
#  'bag': 940,
#  'pleasur': 941,
#  'bak': 942,
#  'pass': 943,
#  'suck': 944,
#  'admir': 945,
#  'appreci': 946,
#  'wast': 947,
#  'greet': 948,
#  'joy': 949,
#  'bold': 950,
#  'omg': 951,
#  'mon': 952,
#  'sam': 953,
#  'http': 954,
#  'deep': 955,
#  'mo': 956,
#  'weed': 957,
#  'copi': 958,
#  'murder': 959,
#  'depend': 960,
#  'definit': 961,
#  'sign': 962,
#  'alert': 963,
#  'pray': 964,
#  'bother': 965,
#  'excus': 966,
#  'muz': 967,
#  'star': 968,
#  'mrng': 969,
#  'umma': 970,
#  'result': 971,
#  'weak': 972,
#  'max': 973,
#  'lift': 974,
#  'immedi': 975,
#  'high': 976,
#  'flight': 977,
#  'hmm': 978,
#  'stupid': 979,
#  'kb': 980,
#  'attend': 981,
#  'manag': 982,
#  'dnt': 983,
#  'men': 984,
#  'wed': 985,
#  'track': 986,
#  'letter': 987,
#  'nyt': 988,
#  'orchard': 989,
#  'noon': 990,
#  'inc': 991,
#  'teach': 992,
#  'lover': 993,
#  'previous': 994,
#  'gettin': 995,
#  'lazi': 996,
#  'style': 997,
#  'reactiv': 998,
#  'less': 999,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)+1
print("vocab_size: ",vocab_size)
# Out:
# vocab_size:  6044

# %%
X_train = [[1] + [tokenizer.word_index.get(word, 2) for word in sentence.split()] for sentence in X_train]
X_test = [[1] + [tokenizer.word_index.get(word, 2) for word in sentence.split()] for sentence in X_test]

# %%
# Pad sequences in X_train and X_test directly
x_train = pad_sequences(X_train, maxlen=max_len)
x_test = pad_sequences(X_test, maxlen=max_len)

# %%
# Get all the words in the model
word_index = tokenizer.word_index
vocab = [word for word, idx in word_index.items()]

# Create a file text_classification_vocab.txt
with open('ta_emm_text_classification_vocab.txt', 'w') as f:
    for i, word in enumerate(vocab):
        f.write(f"{word} {i}\n")

# %% [markdown]
# - Data for test

# %%
# Load file

data_test = pd.read_csv('dataeng_text.csv')

# %%
# Copy the 'sms' column to the 'change_sms' column
data_test['change_sms'] = data_test['sms'].copy()
# Remove leading and trailing whitespaces from the 'change_sms' column
data_test['change_sms'] = data_test['change_sms'].str.strip()
# Convert all characters in the 'change_sms' column to lowercase
data_test['change_sms'] = data_test['change_sms'].str.lower()
# Expand contractions
data_test['change_sms'] = data_test['change_sms'].apply(lambda x: contractions.fix(x))
# Create a new column 'change_sms' by applying the function to 'sms' column
data_test['change_sms'] = data_test['change_sms'].apply(lambda x: change_word_eng(x))
# Remove punctuation
data_test['change_sms'] = data_test['change_sms'].apply(lambda x: re.sub(r'[^\w\d\s]|_\s*$', ' ', x))
# Remove whitespace between terms with single space
data_test['change_sms'] = data_test['change_sms'].apply(lambda x: re.sub(r'\s+', ' ', x))
#tokenize the text in a DataFrame using NLTK
tokenize(data_test , "nltk")
# Lemmatize the 'nltk' column using the lemmatizer function
data_test['nltk'] = lemmatizer(data_test[['nltk']])
# Join the lemmatized tokens back into a single string in each row of the 'nltk' column
data_test['nltk'] = data_test['nltk'].apply(' '.join)
# Stopwords
stop_words = set(stopwords.words('english'))
data_test['nltk'] =data_test['nltk'].apply(lambda x: ' '.join(['' if word.lower().strip() in stop_words else word for word in x.split()]))
# Stemming
ss = SnowballStemmer("english")
data_test['nltk'] = data_test['nltk'].apply(lambda x: ' '.join([ss.stem(term) for term in x.split()]))
# Delete whitespace
data_test['nltk'] = data_test['nltk'].apply(lambda x: ' '.join(word.strip() for word in x.split() if word.strip()))
# Out:
# <ipython-input-34-29701191be3c>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nltk'] = new_values

# %%
data_test
# Out:
#    Unnamed: 0                                                sms  label  \
# 0           0  Beachwaver used their browse and cart abandonm...      0
# 1           1  Since many people eagerly await Memorial Day s...      0
# 2           2  Purity Coffee gave their audience a special Mo...      0
# 3           3  To make the most of increased website traffic ...      0
# 4           4  Thank you for being a valued customer! As a to...      0
# 5           5  You received 3.41 Bitcoin (BTC). To confirm yo...      1
# 6           6  Hi, this is Cynde from HR. We have a couple qu...      1
# 7           7  We’ve detected suspicious activity on your Goo...      1
# 8           8      Your niece has been arrested and needs $7,500      1
# 9           9  Thank you for being a valued customer! As a to...      1
#
#                                           change_sms  \
# 0  beachwaver used their browse and cart abandonm...
# 1  since many people eagerly await memorial day s...
# 2  purity coffee gave their audience a special mo...
# 3  to make the most of increased website traffic ...
# 4  thank you for being a valued customer as a tok...
# 5  you received number number bitcoin btc to conf...
# 6  hi this is cynde from hr we have a couple ques...
# 7  we have detected suspicious activity on your g...
# 8  your niece has been arrested and needs moneysy...
# 9  thank you for being a valued customer as a tok...
#
#                                                 nltk
# 0  beachwav use brows cart abandon remind boost e...
# 1  sinc mani peopl eager await memori day sale sh...
# 2  puriti coffe give audienc special mother day t...
# 3  make increas websit traffic around memori day ...
# 4  thank valu custom token appreci offer discount...
# 5  receiv number number bitcoin btc confirm trans...
# 6  hi cynd hr coupl question regard applic pleas ...
# 7  detect suspici activ googl account follow link...
# 8         niec arrest need moneysymbol number number
# 9  thank valu custom token appreci offer discount...

# %%
# Convert text data in X_train to sequences of integers and pad them to maxlen
datatest = [[1] + [tokenizer.word_index.get(word, 2) for word in sentence.split()] for sentence in data_test['nltk']]
datatest = pad_sequences(datatest , maxlen=max_len)
labeltest = data_test['label'].values

# %% [markdown]
# - Early stopping of model

# %%
# Train the model with early stopping
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3,verbose=1,restore_best_weights=True, )
]

# %% [markdown]
# # LSTM

# %% [markdown]
# - Model Training

# %%
lstm_emm = Sequential()
lstm_emm.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
lstm_emm.add(LSTM(32, return_sequences=True))
lstm_emm.add(Dropout(0.5))
lstm_emm.add(LSTM(32))
lstm_emm.add(Dropout(0.5))
lstm_emm.add(Dense(32, activation='relu'))
lstm_emm.add(Dropout(0.5))
lstm_emm.add(Dense(1, activation='sigmoid'))

lstm_emm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
lstm_emm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 79, 79)            477476
#
#  lstm (LSTM)                 (None, 79, 32)            14336
#
#  dropout (Dropout)           (None, 79, 32)            0
#
#  lstm_1 (LSTM)               (None, 32)                8320
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 501221 (1.91 MB)
# Trainable params: 501221 (1.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the models
history_lstm_emm =lstm_emm.fit(x_train, Y_train, epochs=20, batch_size=32,validation_data=(x_test, Y_test), callbacks=callbacks)
# Out:
# Epoch 1/20
# 224/224 [==============================] - 25s 87ms/step - loss: 0.1653 - acc: 0.9555 - val_loss: 0.0471 - val_acc: 0.9871
# Epoch 2/20
# 224/224 [==============================] - 19s 86ms/step - loss: 0.0280 - acc: 0.9930 - val_loss: 0.0465 - val_acc: 0.9855
# Epoch 3/20
# 224/224 [==============================] - 20s 91ms/step - loss: 0.0105 - acc: 0.9980 - val_loss: 0.0694 - val_acc: 0.9855
# Epoch 4/20
# 224/224 [==============================] - 21s 93ms/step - loss: 0.0057 - acc: 0.9986 - val_loss: 0.1142 - val_acc: 0.9776
# Epoch 5/20
# 224/224 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9996Restoring model weights from the end of the best epoch: 2.
# 224/224 [==============================] - 17s 78ms/step - loss: 0.0026 - acc: 0.9996 - val_loss: 0.1228 - val_acc: 0.9782
# Epoch 5: early stopping

# %% [markdown]
# - Model Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_acc = lstm_emm.evaluate(x_test, Y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
print(f'Test loss: {test_loss * 100:.2f}%')
# Out:
# 56/56 [==============================] - 1s 25ms/step - loss: 0.0465 - acc: 0.9855
# Test accuracy: 98.55%
# Test loss: 4.65%

# %%
from sklearn.metrics import confusion_matrix, classification_report
lstm_emm.evaluate(x_test, Y_test)

y_pred1 = lstm_emm.predict(x_test)
y_pred_binary1 = (y_pred1 > 0.5).astype(int)

conf_matrix1 = confusion_matrix(Y_test, y_pred_binary1)
print("Confusion Matrix:")
print(conf_matrix1)

classification_rep1 = classification_report(Y_test, y_pred_binary1)
print("Classification Report:")
print(classification_rep1)
# Out:
# 56/56 [==============================] - 1s 17ms/step - loss: 0.0465 - acc: 0.9855
# 56/56 [==============================] - 2s 17ms/step
# Confusion Matrix:
# [[901  19]
#  [  7 861]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       920
#            1       0.98      0.99      0.99       868
#
#     accuracy                           0.99      1788
#    macro avg       0.99      0.99      0.99      1788
# weighted avg       0.99      0.99      0.99      1788

# %%
fn.show_result(history_lstm_emm)
# Out:
# Last train accuracy: 0.999580442905426
# Last validation accuracy: 0.9781879186630249

# %%
lstm_emm.inputs[0]
# Out:
# <KerasTensor: shape=(None, 79) dtype=float32 (created by layer 'embedding_input')>

# %%
lstm_emm.outputs[0]
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_1')>

# %% [markdown]
# - Convert tflite model

# %%
run_model = tf.function(lambda x: lstm_emm(x))
# This is important, let's fix the input size.
BATCH_SIZE = 1
STEPS =max_len

concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE,STEPS], lstm_emm.inputs[0].dtype))


# model directory.
MODEL_DIR = "keras_lstm"
lstm_emm.save(MODEL_DIR, save_format="tf", signatures=concrete_func)

converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_DIR)
tflite_model = converter.convert()
# Save the TensorFlow Lite model to a file
file = open('ta_lstm_emm.tflite', 'wb')
file.write(tflite_model)
file.close()

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_lstm_emm.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# Input details: [{'name': 'serving_default_x:0', 'index': 0, 'shape': array([ 1, 79], dtype=int32), 'shape_signature': array([ 1, 79], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall:0', 'index': 44, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([1, 1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %% [markdown]
# - Check the saved Tflite model to see if it works efficiently

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_lstm_emm.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


from sklearn.metrics import accuracy_score

# Initialize an empty list to store the predictions
predictions = []

# Iterate over each sample in the test dataset
for i in range(len(datatest)):
    # Get the input sequence for the current sample and convert it to FLOAT32
    input_sequence_float32 = datatest[i].reshape(1, -1).astype(np.float32)

    # Perform inference
    interpreter.set_tensor(input_details[0]['index'], input_sequence_float32)
    interpreter.invoke()

    # Get the output
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Convert output to binary prediction
    binary_prediction = (output_data > 0.5).astype(int)

    # Append the prediction to the list
    predictions.append(binary_prediction[0])

# accuracy for test data
accuracy1 = accuracy_score(labeltest, predictions)

# Print the accuracy for test data
print("Accuracy :", accuracy1)
# Out:
# Accuracy : 0.6

# %%
# Display the predictions for each text
for i in range(len(data_test)):
    print("Text:", data_test['nltk'][i])
    print("True Label:", labeltest[i])
    print("Predicted Label:", predictions[i])
    print()
# Out:
# Text: beachwav use brows cart abandon remind boost engag revenu memori day sale strateg updat messag highlight final day get number entir site simpl yet effect chang emphas limitedtim natur offer creat great sens urgenc custom shop immedi take advantag deal expir
# True Label: 0
# Predicted Label: [1]
#
# Text: sinc mani peopl eager await memori day sale shop summer cloth normal brand invit custom check late arriv ahead long holiday weekend messag come perfect time anyon consid buy new outfit annual barbecu outdoor gather come
# True Label: 0
# Predicted Label: [0]
#
# Text: puriti coffe give audienc special mother day treat number sitewid plus free ship brand first announc sale sm earli may ensur peopl plenti time order continu promot midnight mother day send mix email sms remind send throughout sale period keep engag convers high
# True Label: 0
# Predicted Label: [0]
#
# Text: make increas websit traffic around memori day dw home launch custom signup unit teas upcom offer captur new subscrib incentiv optin promis alert sm audienc first deal drop also creat special welcom journey new subscrib confirm earli access secur
# True Label: 0
# Predicted Label: [1]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 0
# Predicted Label: [1]
#
# Text: receiv number number bitcoin btc confirm transact visit link
# True Label: 1
# Predicted Label: [1]
#
# Text: hi cynd hr coupl question regard applic pleas call number schedul interview
# True Label: 1
# Predicted Label: [1]
#
# Text: detect suspici activ googl account follow link reset password link
# True Label: 1
# Predicted Label: [1]
#
# Text: niec arrest need moneysymbol number number
# True Label: 1
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 1
# Predicted Label: [1]

# %% [markdown]
# # RNN

# %% [markdown]
# - Model Training

# %%
rnn_emm = Sequential()
rnn_emm.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
rnn_emm.add(SimpleRNN(32, return_sequences=True))
rnn_emm.add(Dropout(0.5))
rnn_emm.add(SimpleRNN(32))
rnn_emm.add(Dropout(0.5))
rnn_emm.add(Dense(32, activation='relu'))
rnn_emm.add(Dropout(0.5))
rnn_emm.add(Dense(units=1, activation='sigmoid'))
rnn_emm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
rnn_emm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 79, 79)            477476
#
#  simple_rnn (SimpleRNN)      (None, 79, 32)            3584
#
#  dropout_3 (Dropout)         (None, 79, 32)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 484229 (1.85 MB)
# Trainable params: 484229 (1.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the models
history_rnn_emm = rnn_emm.fit(x_train, Y_train, epochs=20, batch_size=32,validation_data=(x_test, Y_test), callbacks=callbacks)
# Out:
# Epoch 1/20
# 224/224 [==============================] - 14s 51ms/step - loss: 0.1760 - acc: 0.9400 - val_loss: 0.0520 - val_acc: 0.9849
# Epoch 2/20
# 224/224 [==============================] - 11s 49ms/step - loss: 0.0415 - acc: 0.9912 - val_loss: 0.0716 - val_acc: 0.9821
# Epoch 3/20
# 224/224 [==============================] - 9s 40ms/step - loss: 0.0192 - acc: 0.9959 - val_loss: 0.0644 - val_acc: 0.9815
# Epoch 4/20
# 224/224 [==============================] - ETA: 0s - loss: 0.0077 - acc: 0.9990Restoring model weights from the end of the best epoch: 1.
# 224/224 [==============================] - 11s 48ms/step - loss: 0.0077 - acc: 0.9990 - val_loss: 0.0864 - val_acc: 0.9849
# Epoch 4: early stopping

# %% [markdown]
# - Model Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_acc = rnn_emm.evaluate(x_test, Y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
print(f'Test loss: {test_loss * 100:.2f}%')
# Out:
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0520 - acc: 0.9849
# Test accuracy: 98.49%
# Test loss: 5.20%

# %%
from sklearn.metrics import confusion_matrix, classification_report
rnn_emm.evaluate(x_test, Y_test)

y_pred2 = rnn_emm.predict(x_test)
y_pred_binary2 = (y_pred2> 0.5).astype(int)

conf_matrix2 = confusion_matrix(Y_test, y_pred_binary2)
print("Confusion Matrix:")
print(conf_matrix2)

classification_rep2 = classification_report(Y_test, y_pred_binary2)
print("Classification Report:")
print(classification_rep2)
# Out:
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0520 - acc: 0.9849
# 56/56 [==============================] - 1s 14ms/step
# Confusion Matrix:
# [[909  11]
#  [ 16 852]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       920
#            1       0.99      0.98      0.98       868
#
#     accuracy                           0.98      1788
#    macro avg       0.98      0.98      0.98      1788
# weighted avg       0.98      0.98      0.98      1788

# %%
fn.show_result(history_rnn_emm)
# Out:
# Last train accuracy: 0.9990209937095642
# Last validation accuracy: 0.9848993420600891

# %%
rnn_emm.inputs[0]
# Out:
# <KerasTensor: shape=(None, 79) dtype=float32 (created by layer 'embedding_1_input')>

# %%
rnn_emm.outputs[0]
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_3')>

# %% [markdown]
# - Convert tflite model

# %%
run_model = tf.function(lambda x: rnn_emm(x))
# This is important, let's fix the input size.
BATCH_SIZE = 1
STEPS =max_len

concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE,STEPS], rnn_emm.inputs[0].dtype))


# model directory.
MODEL_DIR = "keras_rnn"
rnn_emm.save(MODEL_DIR, save_format="tf", signatures=concrete_func)

converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_DIR)
tflite_model = converter.convert()
# Save the TensorFlow Lite model to a file
file = open('ta_rnn_emm.tflite', 'wb')
file.write(tflite_model)
file.close()

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_rnn_emm.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# Input details: [{'name': 'serving_default_x:0', 'index': 0, 'shape': array([ 1, 79], dtype=int32), 'shape_signature': array([ 1, 79], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall:0', 'index': 31, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([1, 1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %% [markdown]
# - Check the saved Tflite model to see if it works efficiently

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_rnn_emm.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


from sklearn.metrics import accuracy_score

# Initialize an empty list to store the predictions
predictions = []

# Iterate over each sample in the test dataset
for i in range(len(datatest)):
    # Get the input sequence for the current sample and convert it to FLOAT32
    input_sequence_float32 = datatest[i].reshape(1, -1).astype(np.float32)

    # Perform inference
    interpreter.set_tensor(input_details[0]['index'], input_sequence_float32)
    interpreter.invoke()

    # Get the output
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Convert output to binary prediction
    binary_prediction = (output_data > 0.5).astype(int)

    # Append the prediction to the list
    predictions.append(binary_prediction[0])

# accuracy for test data
accuracy2 = accuracy_score(labeltest, predictions)

# Print the accuracy for test data
print("Accuracy :", accuracy2)
# Out:
# Accuracy : 0.8

# %%
# Display the predictions for each text
for i in range(len(datatest)):
    print("Text:", data_test['nltk'][i])
    print("True Label:", labeltest[i])
    print("Predicted Label:", predictions[i])
    print()
# Out:
# Text: beachwav use brows cart abandon remind boost engag revenu memori day sale strateg updat messag highlight final day get number entir site simpl yet effect chang emphas limitedtim natur offer creat great sens urgenc custom shop immedi take advantag deal expir
# True Label: 0
# Predicted Label: [0]
#
# Text: sinc mani peopl eager await memori day sale shop summer cloth normal brand invit custom check late arriv ahead long holiday weekend messag come perfect time anyon consid buy new outfit annual barbecu outdoor gather come
# True Label: 0
# Predicted Label: [0]
#
# Text: puriti coffe give audienc special mother day treat number sitewid plus free ship brand first announc sale sm earli may ensur peopl plenti time order continu promot midnight mother day send mix email sms remind send throughout sale period keep engag convers high
# True Label: 0
# Predicted Label: [0]
#
# Text: make increas websit traffic around memori day dw home launch custom signup unit teas upcom offer captur new subscrib incentiv optin promis alert sm audienc first deal drop also creat special welcom journey new subscrib confirm earli access secur
# True Label: 0
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 0
# Predicted Label: [1]
#
# Text: receiv number number bitcoin btc confirm transact visit link
# True Label: 1
# Predicted Label: [1]
#
# Text: hi cynd hr coupl question regard applic pleas call number schedul interview
# True Label: 1
# Predicted Label: [1]
#
# Text: detect suspici activ googl account follow link reset password link
# True Label: 1
# Predicted Label: [1]
#
# Text: niec arrest need moneysymbol number number
# True Label: 1
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 1
# Predicted Label: [1]

# %% [markdown]
# # BiLSTM

# %% [markdown]
# - Model Training

# %%
bilstm_emm = Sequential()
bilstm_emm.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
bilstm_emm.add(Bidirectional(LSTM(32, return_sequences=True)))
bilstm_emm.add(Dropout(0.5))
bilstm_emm.add(Bidirectional(LSTM(32)))
bilstm_emm.add(Dropout(0.5))
bilstm_emm.add(Dense(32, activation='relu'))
bilstm_emm.add(Dropout(0.5))
bilstm_emm.add(Dense(1, activation='sigmoid'))
bilstm_emm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
bilstm_emm.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 79, 79)            477476
#
#  bidirectional (Bidirection  (None, 79, 64)            28672
#  al)
#
#  dropout_6 (Dropout)         (None, 79, 64)            0
#
#  bidirectional_1 (Bidirecti  (None, 64)                24832
#  onal)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 533093 (2.03 MB)
# Trainable params: 533093 (2.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_bilstm_emm = bilstm_emm.fit(x_train, Y_train, epochs=20, batch_size=32,validation_data=(x_test, Y_test), callbacks=callbacks)
# Out:
# Epoch 1/20
# 224/224 [==============================] - 42s 148ms/step - loss: 0.1520 - acc: 0.9533 - val_loss: 0.0444 - val_acc: 0.9843
# Epoch 2/20
# 224/224 [==============================] - 31s 140ms/step - loss: 0.0245 - acc: 0.9943 - val_loss: 0.0392 - val_acc: 0.9911
# Epoch 3/20
# 224/224 [==============================] - 30s 132ms/step - loss: 0.0110 - acc: 0.9973 - val_loss: 0.0757 - val_acc: 0.9821
# Epoch 4/20
# 224/224 [==============================] - 29s 131ms/step - loss: 0.0047 - acc: 0.9990 - val_loss: 0.0768 - val_acc: 0.9855
# Epoch 5/20
# 224/224 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9993Restoring model weights from the end of the best epoch: 2.
# 224/224 [==============================] - 29s 131ms/step - loss: 0.0024 - acc: 0.9993 - val_loss: 0.0753 - val_acc: 0.9871
# Epoch 5: early stopping

# %% [markdown]
# - Model Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_acc = bilstm_emm.evaluate(x_test, Y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
print(f'Test loss: {test_loss * 100:.2f}%')
# Out:
# 56/56 [==============================] - 1s 26ms/step - loss: 0.0392 - acc: 0.9911
# Test accuracy: 99.11%
# Test loss: 3.92%

# %%
from sklearn.metrics import confusion_matrix, classification_report
bilstm_emm.evaluate(x_test, Y_test)

y_pred3 = bilstm_emm.predict(x_test)
y_pred_binary3 = (y_pred3> 0.5).astype(int)

conf_matrix3 = confusion_matrix(Y_test, y_pred_binary3)
print("Confusion Matrix:")
print(conf_matrix3)

classification_rep3 = classification_report(Y_test, y_pred_binary3)
print("Classification Report:")
print(classification_rep3)
# Out:
# 56/56 [==============================] - 1s 26ms/step - loss: 0.0392 - acc: 0.9911
# 56/56 [==============================] - 5s 30ms/step
# Confusion Matrix:
# [[914   6]
#  [ 10 858]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       920
#            1       0.99      0.99      0.99       868
#
#     accuracy                           0.99      1788
#    macro avg       0.99      0.99      0.99      1788
# weighted avg       0.99      0.99      0.99      1788

# %%
fn.show_result(history_bilstm_emm)
# Out:
# Last train accuracy: 0.9993007183074951
# Last validation accuracy: 0.9871364831924438

# %%
bilstm_emm.inputs[0]
# Out:
# <KerasTensor: shape=(None, 79) dtype=float32 (created by layer 'embedding_2_input')>

# %%
bilstm_emm.outputs[0]
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_5')>

# %% [markdown]
# - Convert tflite model

# %%
run_model = tf.function(lambda x: bilstm_emm(x))
# This is important, let's fix the input size.
BATCH_SIZE = 1
STEPS = max_len

concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE,STEPS], bilstm_emm.inputs[0].dtype))


# model directory.
MODEL_DIR = "keras_bilstm"
bilstm_emm.save(MODEL_DIR, save_format="tf", signatures=concrete_func)

converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_DIR)
tflite_model = converter.convert()
# Save the TensorFlow Lite model to a file
file = open('ta_bilstm_emm.tflite', 'wb')
file.write(tflite_model)
file.close()

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_bilstm_emm.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# Input details: [{'name': 'serving_default_x:0', 'index': 0, 'shape': array([ 1, 79], dtype=int32), 'shape_signature': array([ 1, 79], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall:0', 'index': 81, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([1, 1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %% [markdown]
# - Check the saved Tflite model to see if it works efficiently

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_bilstm_emm.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


from sklearn.metrics import accuracy_score

# Initialize an empty list to store the predictions
predictions = []

# Iterate over each sample in the test dataset
for i in range(len(datatest)):
    # Get the input sequence for the current sample and convert it to FLOAT32
    input_sequence_float32 = datatest[i].reshape(1, -1).astype(np.float32)

    # Perform inference
    interpreter.set_tensor(input_details[0]['index'], input_sequence_float32)
    interpreter.invoke()

    # Get the output
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Convert output to binary prediction
    binary_prediction = (output_data > 0.5).astype(int)

    # Append the prediction to the list
    predictions.append(binary_prediction[0])

# accuracy for test data
accuracy3 = accuracy_score(labeltest, predictions)

# Print the accuracy for test data
print("Accuracy :", accuracy3)
# Out:
# Accuracy : 0.5

# %%
# Display the predictions for each text
for i in range(len(datatest)):
    print("Text:", data_test['nltk'][i])
    print("True Label:", labeltest[i])
    print("Predicted Label:", predictions[i])
    print()
# Out:
# Text: beachwav use brows cart abandon remind boost engag revenu memori day sale strateg updat messag highlight final day get number entir site simpl yet effect chang emphas limitedtim natur offer creat great sens urgenc custom shop immedi take advantag deal expir
# True Label: 0
# Predicted Label: [0]
#
# Text: sinc mani peopl eager await memori day sale shop summer cloth normal brand invit custom check late arriv ahead long holiday weekend messag come perfect time anyon consid buy new outfit annual barbecu outdoor gather come
# True Label: 0
# Predicted Label: [0]
#
# Text: puriti coffe give audienc special mother day treat number sitewid plus free ship brand first announc sale sm earli may ensur peopl plenti time order continu promot midnight mother day send mix email sms remind send throughout sale period keep engag convers high
# True Label: 0
# Predicted Label: [0]
#
# Text: make increas websit traffic around memori day dw home launch custom signup unit teas upcom offer captur new subscrib incentiv optin promis alert sm audienc first deal drop also creat special welcom journey new subscrib confirm earli access secur
# True Label: 0
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 0
# Predicted Label: [0]
#
# Text: receiv number number bitcoin btc confirm transact visit link
# True Label: 1
# Predicted Label: [0]
#
# Text: hi cynd hr coupl question regard applic pleas call number schedul interview
# True Label: 1
# Predicted Label: [0]
#
# Text: detect suspici activ googl account follow link reset password link
# True Label: 1
# Predicted Label: [0]
#
# Text: niec arrest need moneysymbol number number
# True Label: 1
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 1
# Predicted Label: [0]

# %% [markdown]
# # CNN

# %% [markdown]
# - Model Training

# %%
cnn_emm = Sequential()
cnn_emm.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
cnn_emm.add(Conv1D(32, 5, activation='relu'))
cnn_emm.add(MaxPooling1D(2))
cnn_emm.add(Dropout(0.5))
cnn_emm.add(Conv1D(64, 5, activation='relu'))
cnn_emm.add(MaxPooling1D(2))
cnn_emm.add(Dropout(0.2))
cnn_emm.add(Conv1D(128, 5, activation='relu'))
cnn_emm.add(GlobalMaxPooling1D())
cnn_emm.add(Dropout(0.2))
cnn_emm.add(Flatten())
cnn_emm.add(Dense(64, activation='relu'))
cnn_emm.add(Dropout(0.5))
cnn_emm.add(Dense(1, activation='sigmoid'))
cnn_emm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
cnn_emm.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 79, 79)            477476
#
#  conv1d (Conv1D)             (None, 75, 32)            12672
#
#  max_pooling1d (MaxPooling1  (None, 37, 32)            0
#  D)
#
#  dropout_9 (Dropout)         (None, 37, 32)            0
#
#  conv1d_1 (Conv1D)           (None, 33, 64)            10304
#
#  max_pooling1d_1 (MaxPoolin  (None, 16, 64)            0
#  g1D)
#
#  dropout_10 (Dropout)        (None, 16, 64)            0
#
#  conv1d_2 (Conv1D)           (None, 12, 128)           41088
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 549861 (2.10 MB)
# Trainable params: 549861 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_cnn_emm = cnn_emm.fit(x_train, Y_train, epochs=20, batch_size=32,validation_data=(x_test, Y_test), callbacks=callbacks)
# Out:
# Epoch 1/20
# 224/224 [==============================] - 8s 30ms/step - loss: 0.1608 - acc: 0.9394 - val_loss: 0.0684 - val_acc: 0.9827
# Epoch 2/20
# 224/224 [==============================] - 7s 30ms/step - loss: 0.0408 - acc: 0.9885 - val_loss: 0.0515 - val_acc: 0.9849
# Epoch 3/20
# 224/224 [==============================] - 5s 22ms/step - loss: 0.0174 - acc: 0.9958 - val_loss: 0.0776 - val_acc: 0.9799
# Epoch 4/20
# 224/224 [==============================] - 6s 25ms/step - loss: 0.0139 - acc: 0.9978 - val_loss: 0.0846 - val_acc: 0.9771
# Epoch 5/20
# 224/224 [==============================] - ETA: 0s - loss: 0.0099 - acc: 0.9980Restoring model weights from the end of the best epoch: 2.
# 224/224 [==============================] - 6s 28ms/step - loss: 0.0099 - acc: 0.9980 - val_loss: 0.1050 - val_acc: 0.9787
# Epoch 5: early stopping

# %% [markdown]
# - Model Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_acc = cnn_emm.evaluate(x_test, Y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
print(f'Test loss: {test_loss * 100:.2f}%')
# Out:
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0515 - acc: 0.9849
# Test accuracy: 98.49%
# Test loss: 5.15%

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred4 = cnn_emm.predict(x_test)
y_pred_binary4 = (y_pred4 > 0.5).astype(int)

conf_matrix4 = confusion_matrix(Y_test, y_pred_binary4)
print("Confusion Matrix:")
print(conf_matrix4)

classification_rep4 = classification_report(Y_test, y_pred_binary4)
print("Classification Report:")
print(classification_rep4)
# Out:
# 56/56 [==============================] - 0s 5ms/step
# Confusion Matrix:
# [[911   9]
#  [ 18 850]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       920
#            1       0.99      0.98      0.98       868
#
#     accuracy                           0.98      1788
#    macro avg       0.99      0.98      0.98      1788
# weighted avg       0.98      0.98      0.98      1788

# %%
fn.show_result(history_cnn_emm)
# Out:
# Last train accuracy: 0.9980419874191284
# Last validation accuracy: 0.9787471890449524

# %%
cnn_emm.inputs[0]
# Out:
# <KerasTensor: shape=(None, 79) dtype=float32 (created by layer 'embedding_3_input')>

# %%
cnn_emm.outputs[0]
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_7')>

# %% [markdown]
# - Convert tflite model

# %%
run_model = tf.function(lambda x: cnn_emm(x))
# This is important, let's fix the input size.
BATCH_SIZE = 1
STEPS = max_len

concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE,STEPS], cnn_emm.inputs[0].dtype))


# model directory.
MODEL_DIR = "keras_cnn"
cnn_emm.save(MODEL_DIR, save_format="tf", signatures=concrete_func)

converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_DIR)
tflite_model = converter.convert()
# Save the TensorFlow Lite model to a file
file = open('ta_cnn_emm.tflite', 'wb')
file.write(tflite_model)
file.close()

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_cnn_emm.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# Input details: [{'name': 'serving_default_x:0', 'index': 0, 'shape': array([ 1, 79], dtype=int32), 'shape_signature': array([ 1, 79], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall:0', 'index': 35, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([1, 1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %% [markdown]
# - Check the saved Tflite model to see if it works efficiently

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_cnn_emm.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


from sklearn.metrics import accuracy_score

# Initialize an empty list to store the predictions
predictions = []

# Iterate over each sample in the test dataset
for i in range(len(datatest)):
    # Get the input sequence for the current sample and convert it to FLOAT32
    input_sequence_float32 = datatest[i].reshape(1, -1).astype(np.float32)

    # Perform inference
    interpreter.set_tensor(input_details[0]['index'], input_sequence_float32)
    interpreter.invoke()

    # Get the output
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Convert output to binary prediction
    binary_prediction = (output_data > 0.5).astype(int)

    # Append the prediction to the list
    predictions.append(binary_prediction[0])

# accuracy for test data
accuracy4 = accuracy_score(labeltest, predictions)

# Print the accuracy for test data
print("Accuracy :", accuracy4)
# Out:
# Accuracy : 0.2

# %%
# Display the predictions for each text
for i in range(len(datatest)):
    print("Text:", data_test['nltk'][i])
    print("True Label:", labeltest[i])
    print("Predicted Label:", predictions[i])
    print()
# Out:
# Text: beachwav use brows cart abandon remind boost engag revenu memori day sale strateg updat messag highlight final day get number entir site simpl yet effect chang emphas limitedtim natur offer creat great sens urgenc custom shop immedi take advantag deal expir
# True Label: 0
# Predicted Label: [1]
#
# Text: sinc mani peopl eager await memori day sale shop summer cloth normal brand invit custom check late arriv ahead long holiday weekend messag come perfect time anyon consid buy new outfit annual barbecu outdoor gather come
# True Label: 0
# Predicted Label: [1]
#
# Text: puriti coffe give audienc special mother day treat number sitewid plus free ship brand first announc sale sm earli may ensur peopl plenti time order continu promot midnight mother day send mix email sms remind send throughout sale period keep engag convers high
# True Label: 0
# Predicted Label: [1]
#
# Text: make increas websit traffic around memori day dw home launch custom signup unit teas upcom offer captur new subscrib incentiv optin promis alert sm audienc first deal drop also creat special welcom journey new subscrib confirm earli access secur
# True Label: 0
# Predicted Label: [1]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 0
# Predicted Label: [1]
#
# Text: receiv number number bitcoin btc confirm transact visit link
# True Label: 1
# Predicted Label: [1]
#
# Text: hi cynd hr coupl question regard applic pleas call number schedul interview
# True Label: 1
# Predicted Label: [0]
#
# Text: detect suspici activ googl account follow link reset password link
# True Label: 1
# Predicted Label: [0]
#
# Text: niec arrest need moneysymbol number number
# True Label: 1
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 1
# Predicted Label: [1]

# %% [markdown]
# # GRU

# %% [markdown]
# - Model Training

# %%
gru_emm = Sequential()
gru_emm.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
gru_emm.add(GRU(32, return_sequences=True))
gru_emm.add(Dropout(0.5))
gru_emm.add(GRU(32))
gru_emm.add(Dropout(0.5))
gru_emm.add(Dense(32, activation='relu'))
gru_emm.add(Dropout(0.5))
gru_emm.add(Dense(1, activation='sigmoid'))

gru_emm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
gru_emm.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 79, 79)            477476
#
#  gru (GRU)                   (None, 79, 32)            10848
#
#  dropout_13 (Dropout)        (None, 79, 32)            0
#
#  gru_1 (GRU)                 (None, 32)                6336
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 495749 (1.89 MB)
# Trainable params: 495749 (1.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_gru_emm = gru_emm.fit(x_train, Y_train, epochs=20, batch_size=32,validation_data=(x_test, Y_test), callbacks=callbacks)
# Out:
# Epoch 1/20
# 224/224 [==============================] - 25s 86ms/step - loss: 0.1703 - acc: 0.9421 - val_loss: 0.0429 - val_acc: 0.9860
# Epoch 2/20
# 224/224 [==============================] - 18s 82ms/step - loss: 0.0250 - acc: 0.9948 - val_loss: 0.0559 - val_acc: 0.9855
# Epoch 3/20
# 224/224 [==============================] - 18s 82ms/step - loss: 0.0088 - acc: 0.9980 - val_loss: 0.0544 - val_acc: 0.9855
# Epoch 4/20
# 224/224 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9996Restoring model weights from the end of the best epoch: 1.
# 224/224 [==============================] - 19s 86ms/step - loss: 0.0024 - acc: 0.9996 - val_loss: 0.0653 - val_acc: 0.9883
# Epoch 4: early stopping

# %% [markdown]
# - Model Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_acc = gru_emm.evaluate(x_test, Y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
print(f'Test loss: {test_loss * 100:.2f}%')
# Out:
# 56/56 [==============================] - 1s 16ms/step - loss: 0.0429 - acc: 0.9860
# Test accuracy: 98.60%
# Test loss: 4.29%

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred5 = gru_emm.predict(x_test)
y_pred_binary5 = (y_pred5 > 0.5).astype(int)

conf_matrix5 = confusion_matrix(Y_test, y_pred_binary5)
print("Confusion Matrix:")
print(conf_matrix5)

classification_rep5 = classification_report(Y_test, y_pred_binary5)
print("Classification Report:")
print(classification_rep5)
# Out:
# 56/56 [==============================] - 2s 22ms/step
# Confusion Matrix:
# [[904  16]
#  [  9 859]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       920
#            1       0.98      0.99      0.99       868
#
#     accuracy                           0.99      1788
#    macro avg       0.99      0.99      0.99      1788
# weighted avg       0.99      0.99      0.99      1788

# %%
fn.show_result(history_gru_emm)
# Out:
# Last train accuracy: 0.999580442905426
# Last validation accuracy: 0.9882550239562988

# %%
gru_emm.inputs[0]
# Out:
# <KerasTensor: shape=(None, 79) dtype=float32 (created by layer 'embedding_4_input')>

# %%
gru_emm.outputs[0]
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_9')>

# %% [markdown]
# - Convert tflite model

# %%
run_model = tf.function(lambda x: gru_emm(x))
# This is important, let's fix the input size.
BATCH_SIZE = 1
STEPS =max_len

concrete_func = run_model.get_concrete_function(
    tf.TensorSpec([BATCH_SIZE,STEPS], gru_emm.inputs[0].dtype))


# model directory.
MODEL_DIR = "keras_gru"
gru_emm.save(MODEL_DIR, save_format="tf", signatures=concrete_func)

converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_DIR)
tflite_model = converter.convert()
# Save the TensorFlow Lite model to a file
file = open('ta_gru_emm.tflite', 'wb')
file.write(tflite_model)
file.close()

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_gru_emm.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input details:", input_details)
print("Output details:", output_details)
# Out:
# Input details: [{'name': 'serving_default_x:0', 'index': 0, 'shape': array([ 1, 79], dtype=int32), 'shape_signature': array([ 1, 79], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall:0', 'index': 35, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([1, 1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %% [markdown]
# - Check the saved Tflite model to see if it works efficiently

# %%
# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path='ta_gru_emm.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


from sklearn.metrics import accuracy_score

# Initialize an empty list to store the predictions
predictions = []

# Iterate over each sample in the test dataset
for i in range(len(datatest)):
    # Get the input sequence for the current sample and convert it to FLOAT32
    input_sequence_float32 = datatest[i].reshape(1, -1).astype(np.float32)

    # Perform inference
    interpreter.set_tensor(input_details[0]['index'], input_sequence_float32)
    interpreter.invoke()

    # Get the output
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Convert output to binary prediction
    binary_prediction = (output_data > 0.5).astype(int)

    # Append the prediction to the list
    predictions.append(binary_prediction[0])

# accuracy for test data
accuracy5 = accuracy_score(labeltest, predictions)

# Print the accuracy for test data
print("Accuracy :", accuracy5)
# Out:
# Accuracy : 0.8

# %%
# Display the predictions for each text
for i in range(len(data_test)):
    print("Text:", data_test['nltk'][i])
    print("True Label:", labeltest[i])
    print("Predicted Label:", predictions[i])
    print()
# Out:
# Text: beachwav use brows cart abandon remind boost engag revenu memori day sale strateg updat messag highlight final day get number entir site simpl yet effect chang emphas limitedtim natur offer creat great sens urgenc custom shop immedi take advantag deal expir
# True Label: 0
# Predicted Label: [0]
#
# Text: sinc mani peopl eager await memori day sale shop summer cloth normal brand invit custom check late arriv ahead long holiday weekend messag come perfect time anyon consid buy new outfit annual barbecu outdoor gather come
# True Label: 0
# Predicted Label: [0]
#
# Text: puriti coffe give audienc special mother day treat number sitewid plus free ship brand first announc sale sm earli may ensur peopl plenti time order continu promot midnight mother day send mix email sms remind send throughout sale period keep engag convers high
# True Label: 0
# Predicted Label: [0]
#
# Text: make increas websit traffic around memori day dw home launch custom signup unit teas upcom offer captur new subscrib incentiv optin promis alert sm audienc first deal drop also creat special welcom journey new subscrib confirm earli access secur
# True Label: 0
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 0
# Predicted Label: [1]
#
# Text: receiv number number bitcoin btc confirm transact visit link
# True Label: 1
# Predicted Label: [1]
#
# Text: hi cynd hr coupl question regard applic pleas call number schedul interview
# True Label: 1
# Predicted Label: [1]
#
# Text: detect suspici activ googl account follow link reset password link
# True Label: 1
# Predicted Label: [1]
#
# Text: niec arrest need moneysymbol number number
# True Label: 1
# Predicted Label: [0]
#
# Text: thank valu custom token appreci offer discountoff visit store locat use code promo code onlin websit appreci loyalti
# True Label: 1
# Predicted Label: [1]

# %% [markdown]
# # BERT

# %%
# !pip install tensorflow-text==2.15.0
# Out:
# Collecting tensorflow-text==2.15.0
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text==2.15.0) (0.16.1)
# Requirement already satisfied: tensorflow<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text==2.15.0) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.15.0)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub>=0.13.0->tensorflow-text==2.15.0) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text==2.15.0) (3.2.2)
# Installing collected packages: tensorflow-text
# Successfully installed tensorflow-text-2.15.0

# %%
import tensorflow_hub as hub
import tensorflow_text as text

# %% [markdown]
# - Model Training

# %%
# loading train test split
from sklearn.model_selection import train_test_split
X_train1, X_test1 , y_train1, y_test1 = train_test_split(final_df['nltk'], final_df['label'],
                                                    stratify = final_df['label'])

# %%
# downloading preprocessing files and model
bert_preprocessor = hub.KerasLayer('https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3')
bert_encoder = hub.KerasLayer('https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4')

# %%
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='inputs')

preprocessed_text = bert_preprocessor(text_input)
embeed = bert_encoder(preprocessed_text)
dropout = tf.keras.layers.Dropout(0.1, name = 'Dropout')(embeed['pooled_output'])
outputs = tf.keras.layers.Dense(1, activation = 'sigmoid', name = 'Dense')(dropout)
# creating final model
bert_emm = tf.keras.Model(inputs = [text_input], outputs = [outputs])

# %%
# compiling our model
bert_emm.compile(optimizer ='adam',
               loss = 'binary_crossentropy',
                metrics=['acc'])

# %%
# check the summary of the model
bert_emm.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None,)]                    0         []
#
#  keras_layer (KerasLayer)    {'input_word_ids': (None,    0         ['inputs[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_type_ids': (None,
#                               128)}
#
#  keras_layer_1 (KerasLayer)  {'sequence_output': (None,   1094822   ['keras_layer[0][0]',
#                               128, 768),                  41         'keras_layer[0][1]',
#                               'default': (None, 768),                'keras_layer[0][2]']
#                               'encoder_outputs': [(None
#                              , 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768),
#                               (None, 128, 768)],
#                               'pooled_output': (None, 7
#                              68)}
#
#  Dropout (Dropout)           (None, 768)                  0         ['keras_layer_1[0][13]']
#
#  Dense (Dense)               (None, 1)                    769       ['Dropout[0][0]']
#
# ==================================================================================================
# Total params: 109483010 (417.64 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 109482241 (417.64 MB)
# __________________________________________________________________________________________________

# %%
# Replace missing values with an empty string
X_train1 = X_train1.fillna('')
X_test1 = X_test1.fillna('')

# %%
history_bert_emm = bert_emm.fit(X_train1, y_train1, epochs=20, batch_size=32,validation_data=(X_test1, y_test1), callbacks=callbacks)
# Out:
# Epoch 1/20
# 210/210 [==============================] - 128s 524ms/step - loss: 0.2640 - acc: 0.8962 - val_loss: 0.1822 - val_acc: 0.9356
# Epoch 2/20
# 210/210 [==============================] - 91s 435ms/step - loss: 0.1709 - acc: 0.9366 - val_loss: 0.1408 - val_acc: 0.9508
# Epoch 3/20
# 210/210 [==============================] - 110s 523ms/step - loss: 0.1411 - acc: 0.9470 - val_loss: 0.1226 - val_acc: 0.9562
# Epoch 4/20
# 210/210 [==============================] - 110s 524ms/step - loss: 0.1299 - acc: 0.9539 - val_loss: 0.1135 - val_acc: 0.9579
# Epoch 5/20
# 210/210 [==============================] - 91s 434ms/step - loss: 0.1200 - acc: 0.9576 - val_loss: 0.1071 - val_acc: 0.9602
# Epoch 6/20
# 210/210 [==============================] - 110s 523ms/step - loss: 0.1142 - acc: 0.9593 - val_loss: 0.1030 - val_acc: 0.9638
# Epoch 7/20
# 210/210 [==============================] - 91s 435ms/step - loss: 0.1075 - acc: 0.9611 - val_loss: 0.0962 - val_acc: 0.9673
# Epoch 8/20
# 210/210 [==============================] - 91s 432ms/step - loss: 0.1042 - acc: 0.9612 - val_loss: 0.0928 - val_acc: 0.9691
# Epoch 9/20
# 210/210 [==============================] - 115s 550ms/step - loss: 0.0986 - acc: 0.9666 - val_loss: 0.0921 - val_acc: 0.9696
# Epoch 10/20
# 210/210 [==============================] - 110s 526ms/step - loss: 0.0981 - acc: 0.9661 - val_loss: 0.0899 - val_acc: 0.9709
# Epoch 11/20
# 210/210 [==============================] - 110s 524ms/step - loss: 0.0942 - acc: 0.9675 - val_loss: 0.0871 - val_acc: 0.9714
# Epoch 12/20
# 210/210 [==============================] - 110s 523ms/step - loss: 0.0918 - acc: 0.9672 - val_loss: 0.0880 - val_acc: 0.9705
# Epoch 13/20
# 210/210 [==============================] - 110s 523ms/step - loss: 0.0904 - acc: 0.9705 - val_loss: 0.0877 - val_acc: 0.9705
# Epoch 14/20
# 210/210 [==============================] - 110s 523ms/step - loss: 0.0881 - acc: 0.9691 - val_loss: 0.0851 - val_acc: 0.9718
# Epoch 15/20
# 210/210 [==============================] - 110s 524ms/step - loss: 0.0898 - acc: 0.9703 - val_loss: 0.0804 - val_acc: 0.9754
# Epoch 16/20
# 210/210 [==============================] - 93s 444ms/step - loss: 0.0860 - acc: 0.9699 - val_loss: 0.0793 - val_acc: 0.9754
# Epoch 17/20
# 210/210 [==============================] - 109s 522ms/step - loss: 0.0856 - acc: 0.9700 - val_loss: 0.0790 - val_acc: 0.9758
# Epoch 18/20
# 210/210 [==============================] - 110s 523ms/step - loss: 0.0870 - acc: 0.9693 - val_loss: 0.0776 - val_acc: 0.9754
# Epoch 19/20
# 210/210 [==============================] - 90s 430ms/step - loss: 0.0820 - acc: 0.9721 - val_loss: 0.0789 - val_acc: 0.9727
# Epoch 20/20
# 210/210 [==============================] - 91s 435ms/step - loss: 0.0814 - acc: 0.9705 - val_loss: 0.0762 - val_acc: 0.9745

# %% [markdown]
# - Model Evaluation

# %%
# Evaluate the model on the test set
classification_metrics = bert_emm.evaluate(X_test1,y_test1)

test_loss = classification_metrics[0]
test_acc = classification_metrics[1]

print(f'Test accuracy: {test_acc * 100:.2f}%')
print(f'Test loss: {test_loss * 100:.2f}%')
# Out:
# 70/70 [==============================] - 23s 323ms/step - loss: 0.0762 - acc: 0.9745
# Test accuracy: 97.45%
# Test loss: 7.62%

# %%
fn.show_result(history_bert_emm)
# Out:
# Last train accuracy: 0.9704610109329224
# Last validation accuracy: 0.9744966626167297

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred6 = bert_emm.predict(X_test1)
y_pred_binary6 = (y_pred6 > 0.5).astype(int)

conf_matrix6 = confusion_matrix(y_test1, y_pred_binary6)
print("Confusion Matrix:")
print(conf_matrix6)

classification_rep6 = classification_report(y_test1, y_pred_binary6)
print("Classification Report:")
print(classification_rep6)
# Out:
# 70/70 [==============================] - 23s 322ms/step
# Confusion Matrix:
# [[1098   20]
#  [  37 1080]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1118
#            1       0.98      0.97      0.97      1117
#
#     accuracy                           0.97      2235
#    macro avg       0.97      0.97      0.97      2235
# weighted avg       0.97      0.97      0.97      2235

# %% [markdown]
# - Save model

# %%
bert_emm.save('ta_bert_emm.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
